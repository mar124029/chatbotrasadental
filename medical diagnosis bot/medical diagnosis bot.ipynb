# %% [markdown]
# ### Part1 :
# ### Prepare input data for diagnosis portion

# %%
import pandas as pd
import spacy
import random
import re
# Out:
# 2023-05-26 09:30:04.105800: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-26 09:30:04.232519: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-26 09:30:04.233510: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-26 09:30:05.087525: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
nlp = spacy.load('en_core_web_md')

# %%
def get_sentence_vectors(text, nlp):
    
    # get tokens for each word in a sentence
    embedding = nlp(text).vector.tolist()
    
    return embedding

# %% [markdown]
# Import and merge data

# %%
illness_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/dia_t.csv')
symptom_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/sym_t.csv')
links_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/diffsydiw.csv')

# %%
illness_df.head()
# Out:
#    did                                           diagnose
# 0    1  Abdominal aortic aneurysm
# (enlarged major bloo...
# 1    2                                 Abdominal swelling
# 2    3                                   Abdominal trauma
# 3    4                               Abrasions
#  (scrapes)
# 4    5  ACE inhibitor induced cough
# blood pressure med...

# %%
symptom_df.head()
# Out:
#    syd                      symptom
# 0    1         Upper abdominal pain
# 1    2         Lower abdominal pain
# 2    3  Abscess (Collection of pus)
# 3    4                Alcohol abuse
# 4    5        Anxiety (Nervousness)

# %%
source_data = (links_df
               .merge(illness_df, on="did")
               .merge(symptom_df, on="syd"))
source_data
# Out:
#         syd     did  wei                                           diagnose  \
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
source_data

# %%
# Remove missing data and select columns we needed

source_data = source_data.loc[~(source_data['symptom'].isna()) & ~(source_data['diagnose'].isna()),['did', 'syd', 'diagnose', 'symptom']]

source_data.columns = ['illness_id', 'symptom_id', 'illness', 'symptom']

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis
# inflammation of the gallbladder
# 1                Choledocholithiasis
# stone in bile duct
# 2                             Cholelithiasis
# gallstones
# 3                                          Constipation
# 4                           Gastric ulcer
# stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564                                 Hair loss
# alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %%
# tidy up some new messy characters
source_data['illness'] = source_data['illness'].str.replace('\x0b', ' ')
source_data['symptom'] = source_data['symptom'].str.replace('\x0b', ' ')

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis inflammation of the gallbladder
# 1                Choledocholithiasis stone in bile duct
# 2                             Cholelithiasis gallstones
# 3                                          Constipation
# 4                           Gastric ulcer stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma skin cancer on ...
# 5564                                 Hair loss alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %% [markdown]
# Use our function to convert each symptom to a vector representation we can then save our symptom data down to the data folder

# %%
symptom_df = symptom_df.loc[~symptom_df['symptom'].isna()]

symptom_df['embedding'] = symptom_df.apply(lambda row: get_sentence_vectors(row['symptom'], nlp), axis=1)
# symptom_df.columns = ['symptom_id', 'symptom', 'symptom_vector']

# %%
symptom_df
# Out:
#      symptom_id                          symptom  \
# 0             1             Upper abdominal pain
# 1             2             Lower abdominal pain
# 2             3      Abscess (Collection of pus)
# 3             4                    Alcohol abuse
# 4             5            Anxiety (Nervousness)
# ..          ...                              ...
# 267         295                 Nipple discharge
# 268         301  Shoulder stiffness or tightness
# 269         303       Arm stiffness or tightness
# 270         304              High blood pressure
# 271         306                 High blood sugar
#
#                                         symptom_vector
# 0    [-0.3931533396244049, -1.122189998626709, -2.3...
# 1    [0.11224666982889175, -1.3984565734863281, -2....
# 2    [-4.394866943359375, -5.325353145599365, 3.294...
# 3    [-1.0100150108337402, -3.2876999378204346, -1....
# 4    [-2.1256749629974365, -4.137800216674805, 4.55...
# ..                                                 ...
# 267  [-1.7614949941635132, 0.5206300020217896, -1.9...
# 268  [-1.2457798719406128, 2.181957483291626, -6.26...
# 269  [-1.7361524105072021, 1.2958674430847168, -4.8...
# 270  [-0.959559977054596, 0.45383667945861816, -2.6...
# 271  [-0.032566625624895096, -1.4907633066177368, -...
#
# [246 rows x 3 columns]

# %%
# remove messy charecters

symptom_df['symptom'] = symptom_df['symptom'].str.replace('\x0b', ' ')

# %%
source_data.to_pickle('data/source_data.pkl')
symptom_df.to_pickle('data/symptoms.pkl')

# %% [markdown]
# ### Create a vector of symtpoms for each illness described in the data

# %% [markdown]
# Here we will loop through each illness described in the dataset
# and flag (with a 1 or 0) each of the symptoms of that illness.
# We will do then compare a list of flagged symptoms described by
# the user to this using a cosine similarity function to diagnose
# a potential illness.

# %%
# list of illness 
illnesses = list(source_data['illness'].drop_duplicates())

# list we will use store our illness vectors 
symptom_vectors = []

for illness in illnesses:
    
    illnesses_symptoms = list(source_data.loc[source_data['illness'] == illness, 'symptom'].drop_duplicates())
    
    symptom_df['related_to_illness'] = 0
    symptom_df.loc[symptom_df['symptom'].isin(illnesses_symptoms), "related_to_illness"] = 1
    
    symptom_vectors.append(list(symptom_df["related_to_illness"]))
    
diagnosis_data = pd.DataFrame({"illness":illnesses,
                                "illness_vector":symptom_vectors})

# %%
diagnosis_data.to_pickle("data/diagnosis_data.pkl")

# %% [markdown]
# ### Part 2:
# ### Generate training samples with flagged entities

# %% [markdown]
# In this part we will attempt to generate some training examples for the NLU model to understand how our users will describe symtoms to the chat bot. To do this we simply loop through our symptoms, sometimes combining them before appending them to different beginnings/endings.
#
# We also make sure to tag any symptom describtions as a symptom entity, which will be understood by Rasa's NLU model. You can see this is accomplished by inserting '(symptom)' beside any mention of symptoms.
#
# The output of this is inserted into nlu.md within the main project.

# %%
number_of_symtoms = [1, 2, 3, 4]
start_of_description = [
    "I have",
    "I'm suffering from",
    "I have really bad",
    "My symptoms are",
    "For the last few days I have had",
    "My husband is suffering from" ,
    "My wife is suffering from",
    "My son is suffering from",
    "My daughter is suffering from",
    "My child is suffering from",
    "I don't feel well, I have"
]

# Get some examples of users describing different number of symtoms 

for symptoms_count in number_of_symtoms:
    
    # make 100 example of each number of symtoms 
    for ex in range(1, 101):
        
        description_beginning = random.choice(start_of_description)
        
        # collect some random symtoms 
        symptom_1 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_2 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_3 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_4 = symptom_df['symptom'].sample(1).iloc[0].lower()
        
        symptoms = [symptom_1, symptom_2, symptom_3, symptom_4]
        symptom_entity = []
        
        # Remove paranthases from symptoms and add nessecary entity tags to symtoms 
        for symptom in symptoms:
            symptom = re.sub(r"\([^)]+\)", "", symptom).strip()
            symptom = f"[{symptom}](symptom)"
            symptom_entity.append(symptom)
            
        symptom_1 = symptom_entity[0]
        symptom_2 = symptom_entity[1]
        symptom_3 = symptom_entity[2]
        symptom_4 = symptom_entity[3]
        
        # Create the training sample strig 
        
        if symptoms_count == 1:
            
            symptom_string = f"- {description_beginning} {symptom_1}"
            
        if symptoms_count == 2:
            
            symptom_string = f"- {description_beginning} {symptom_1} and {symptom_2}"
            
        if symptoms_count == 3:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, and {symptom_3}"
            
        if symptoms_count == 4:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, {symptom_3}, {symptom_4}"
        
        print(symptom_string)
# Out:
# - My wife is suffering from [chest pressure](symptom)
# - For the last few days I have had [lump or mass of breast](symptom)
# - My son is suffering from [skin bumps](symptom)
# - I'm suffering from [rectal pain](symptom)
# - I'm suffering from [anxiety](symptom)
# - I don't feel well, I have [dementia](symptom)
# - My symptoms are [fever in the returning traveler](symptom)
# - For the last few days I have had [lethargy](symptom)
# - My child is suffering from [traveler's diarrhea](symptom)
# - I have really bad [painful rash](symptom)
# - My son is suffering from [neck swelling](symptom)
# - I have really bad [elbow swelling](symptom)
# - My daughter is suffering from [memory loss](symptom)
# - I have really bad [visual flashing lights](symptom)
# - My son is suffering from [bleeding gums](symptom)
# - For the last few days I have had [nasal congestion](symptom)
# - My daughter is suffering from [frequent urination](symptom)
# - I don't feel well, I have [vaginal pain](symptom)
# - My daughter is suffering from [ingestion](symptom)
# - I don't feel well, I have [night sweats](symptom)
# - I have [fever in the returning traveler](symptom)
# - My child is suffering from [sweating](symptom)
# - I'm suffering from [blurry vision](symptom)
# - I'm suffering from [vaginal pain](symptom)
# - My wife is suffering from [foot pain](symptom)
# - My daughter is suffering from [leg numbness](symptom)
# - For the last few days I have had [leg redness](symptom)
# - I have really bad [alcohol abuse](symptom)
# - My husband is suffering from [skin bumps](symptom)
# - My child is suffering from [painful urination](symptom)
# - For the last few days I have had [shoulder stiffness or tightness](symptom)
# - My daughter is suffering from [seizure](symptom)
# - My symptoms are [anxiety](symptom)
# - My son is suffering from [shortness of breath](symptom)
# - My daughter is suffering from [itchy eyes](symptom)
# - I don't feel well, I have [chest pain](symptom)
# - For the last few days I have had [headache and weakness](symptom)
# - I'm suffering from [chest burning](symptom)
# - I don't feel well, I have [limping in a child](symptom)
# - I have really bad [sleep disorders](symptom)
# - My son is suffering from [congestion in chest or lungs](symptom)
# - I don't feel well, I have [arm cut](symptom)
# - My wife is suffering from [tongue swelling](symptom)
# - My symptoms are [retaining fluid](symptom)
# - My daughter is suffering from [chills](symptom)
# - I don't feel well, I have [inconsolable baby](symptom)
# - For the last few days I have had [skin swelling](symptom)
# - I have [confusion and headache](symptom)
# - I'm suffering from [hives](symptom)
# - My symptoms are [difficulty breathing](symptom)
# - My son is suffering from [foot itching](symptom)
# - My wife is suffering from [arm numbness](symptom)
# - My husband is suffering from [foot cut](symptom)
# - My wife is suffering from [drooling](symptom)
# - I have really bad [headache and weakness](symptom)
# - I have [snake bite](symptom)
# - I have really bad [high blood pressure](symptom)
# - For the last few days I have had [neck stiffness or tightness](symptom)
# - I'm suffering from [heel pain](symptom)
# - My symptoms are [choking](symptom)
# - My daughter is suffering from [neck swelling](symptom)
# - My symptoms are [cough](symptom)
# - My wife is suffering from [face numbness](symptom)
# - I have [head injury](symptom)
# - My child is suffering from [scrotal swelling](symptom)
# - My child is suffering from [unsteady gait](symptom)
# - My daughter is suffering from [toe pain](symptom)
# - My daughter is suffering from [sinus pain and pressure](symptom)
# - My child is suffering from [nasal congestion](symptom)
# - I have really bad [hemoptysis](symptom)
# - My son is suffering from [anxiety](symptom)
# - My son is suffering from [eye floaters](symptom)
# - My daughter is suffering from [arm itching](symptom)
# - I don't feel well, I have [frequent urination](symptom)
# - My symptoms are [foot itching](symptom)
# - My daughter is suffering from [leg ache or pain](symptom)
# - My wife is suffering from [dark stools](symptom)
# - I have [increased urination](symptom)
# - I'm suffering from [fainting](symptom)
# - My son is suffering from [amenorrhea](symptom)
# - I have [elbow ache or pain](symptom)
# - My child is suffering from [maroon stools](symptom)
# - I'm suffering from [weight loss, unexplained](symptom)
# - My wife is suffering from [heart pulsations and palpitations](symptom)
# - I have [muscle pain](symptom)
# - My daughter is suffering from [difficulty breathing](symptom)
# - My symptoms are [shortness of breath](symptom)
# - For the last few days I have had [muscle pain](symptom)
# - I don't feel well, I have [vaginal bleeding during pregnancy](symptom)
# - I don't feel well, I have [leg ache or pain](symptom)
# - My husband is suffering from [calf pain](symptom)
# - My child is suffering from [overdose](symptom)
# - I have [elbow swelling](symptom)
# - My son is suffering from [hand, finger ache or pain](symptom)
# - My symptoms are [hand cut](symptom)
# - My symptoms are [skin itching](symptom)
# - For the last few days I have had [shoulder ache or pain](symptom)
# - My husband is suffering from [nipple discharge](symptom)
# - My symptoms are [impotence](symptom)
# - For the last few days I have had [amenorrhea](symptom)
# - For the last few days I have had [skin growths](symptom) and [bleeding in brain](symptom)
# - My son is suffering from [armpit pain](symptom) and [eye pain](symptom)
# - My wife is suffering from [dry skin](symptom) and [behavioral problem](symptom)
# - My wife is suffering from [increased urination](symptom) and [hoarse voice](symptom)
# - My son is suffering from [increased facial hair](symptom) and [calf swelling](symptom)
# - For the last few days I have had [nail injury](symptom) and [drooling](symptom)
# - I have really bad [jaw pain](symptom) and [limping in a child](symptom)
# - I have [tired](symptom) and [bleeding gums](symptom)
# - I have [amenorrhea](symptom) and [shoulder stiffness or tightness](symptom)
# - My wife is suffering from [kidney pain](symptom) and [neck swelling](symptom)
# - I have really bad [foot itching](symptom) and [hand redness](symptom)
# - I have [rectal pain](symptom) and [arm redness](symptom)
# - My son is suffering from [pain or soreness of breast](symptom) and [bleeding in brain](symptom)
# - For the last few days I have had [nasal bleeding](symptom) and [bloody diarrhea](symptom)
# - My symptoms are [swelling](symptom) and [bloody diarrhea](symptom)
# - I don't feel well, I have [headache after trauma](symptom) and [foot redness](symptom)
# - I'm suffering from [trauma](symptom) and [sneezing](symptom)
# - My son is suffering from [infertility](symptom) and [chest pressure](symptom)
# - My son is suffering from [wrist pain](symptom) and [chest pain](symptom)
# - My child is suffering from [hand numbness](symptom) and [agitated](symptom)
# - My child is suffering from [swollen lymph nodes](symptom) and [groin pain](symptom)
# - For the last few days I have had [suicidal tendencies](symptom) and [fever in the returning traveler](symptom)
# - For the last few days I have had [skin trauma](symptom) and [foot swelling](symptom)
# - I have really bad [pregnancy problem](symptom) and [throat pain](symptom)
# - My daughter is suffering from [dementia](symptom) and [steatorrhea](symptom)
# - My daughter is suffering from [fainting](symptom) and [insomnia](symptom)
# - My wife is suffering from [toe pain](symptom) and [shortness of breath](symptom)
# - I have really bad [penis inflammation or swelling](symptom) and [alcohol abuse](symptom)
# - I have [alcohol abuse](symptom) and [visual problems](symptom)
# - My husband is suffering from [melena](symptom) and [general weakness](symptom)
# - For the last few days I have had [foot swelling](symptom) and [skin pain](symptom)
# - I'm suffering from [blood in urine](symptom) and [blurry vision](symptom)
# - My wife is suffering from [arm numbness](symptom) and [pustule](symptom)
# - My child is suffering from [insomnia](symptom) and [low heart rate](symptom)
# - My child is suffering from [rectal swelling](symptom) and [skin sores](symptom)
# - My wife is suffering from [vaginal bleeding after menopause](symptom) and [penis pain](symptom)
# - My wife is suffering from [obesity](symptom) and [maroon stools](symptom)
# - My child is suffering from [vaginal pain](symptom) and [wheezing](symptom)
# - My daughter is suffering from [nasal congestion](symptom) and [skin itching](symptom)
# - I have really bad [dementia](symptom) and [wrist pain](symptom)
# - I have [pustule](symptom) and [arm redness](symptom)
# - I have really bad [itchy eyes](symptom) and [nausea](symptom)
# - My symptoms are [high blood sugar](symptom) and [hoarse voice](symptom)
# - My wife is suffering from [ear pressure](symptom) and [leg itching](symptom)
# - My child is suffering from [change in behavior](symptom) and [chest burning](symptom)
# - My wife is suffering from [shin pain](symptom) and [penis pain](symptom)
# - I have [itchy eyes](symptom) and [infertility](symptom)
# - My son is suffering from [eye pain](symptom) and [memory loss](symptom)
# - For the last few days I have had [leg itching](symptom) and [foot itching](symptom)
# - I don't feel well, I have [shoulder ache or pain](symptom) and [arm numbness](symptom)
# - My husband is suffering from [dizziness](symptom) and [hives](symptom)
# - My son is suffering from [alcohol abuse](symptom) and [upper abdominal pain](symptom)
# - My daughter is suffering from [foot swelling](symptom) and [chest pressure](symptom)
# - My husband is suffering from [back ache or pain](symptom) and [hip pain](symptom)
# - My son is suffering from [pregnancy problem](symptom) and [dry skin](symptom)
# - I have really bad [skin growths](symptom) and [failure to thrive](symptom)
# - I don't feel well, I have [overdose](symptom) and [itchy rash](symptom)
# - My son is suffering from [joint stiffness](symptom) and [eye redness](symptom)
# - My daughter is suffering from [fever](symptom) and [mouth pain](symptom)
# - My son is suffering from [elbow swelling](symptom) and [penile discharge](symptom)
# - My son is suffering from [infertility](symptom) and [arm stiffness or tightness](symptom)
# - I have really bad [learning difficulties](symptom) and [wrist pain](symptom)
# - My husband is suffering from [abdominal swelling](symptom) and [dementia](symptom)
# - I'm suffering from [skin itching](symptom) and [confusion](symptom)
# - My husband is suffering from [arm cut](symptom) and [arm numbness](symptom)
# - My daughter is suffering from [dementia](symptom) and [flatulence](symptom)
# - I'm suffering from [insomnia](symptom) and [discharge from ear](symptom)
# - My wife is suffering from [leg cut](symptom) and [calf pain](symptom)
# - My wife is suffering from [double vision](symptom) and [alcohol abuse](symptom)
# - My husband is suffering from [leg ache or pain](symptom) and [penis inflammation or swelling](symptom)
# - I have really bad [pain or soreness of breast](symptom) and [lump or mass of breast](symptom)
# - I have really bad [upper leg pain](symptom) and [fever in the returning traveler](symptom)
# - My husband is suffering from [shoulder ache or pain](symptom) and [painful urination](symptom)
# - My wife is suffering from [low heart rate](symptom) and [knee pain](symptom)
# - My symptoms are [nail injury](symptom) and [neck ache or pain](symptom)
# - For the last few days I have had [lethargy](symptom) and [drooling](symptom)
# - My child is suffering from [neck swelling](symptom) and [ear swelling](symptom)
# - My wife is suffering from [heart murmur](symptom) and [sleep disorders](symptom)
# - My daughter is suffering from [cranky, crying, fussy, irritable child](symptom) and [blister](symptom)
# - I don't feel well, I have [nasal injury](symptom) and [increased facial hair](symptom)
# - My wife is suffering from [liver failure](symptom) and [incontinence](symptom)
# - My daughter is suffering from [facial pain](symptom) and [snoring](symptom)
# - My child is suffering from [trauma](symptom) and [snake bite](symptom)
# - I have [pain in the ear](symptom) and [hot flashes](symptom)
# - My husband is suffering from [weakness](symptom) and [eye pain](symptom)
# - My daughter is suffering from [melena](symptom) and [confusion](symptom)
# - My daughter is suffering from [confusion](symptom) and [sweating](symptom)
# - For the last few days I have had [confusion and headache](symptom) and [shortness of breath](symptom)
# - My wife is suffering from [hair loss](symptom) and [double vision](symptom)
# - I have [elbow ache or pain](symptom) and [sore throat](symptom)
# - My husband is suffering from [pain or soreness of breast](symptom) and [seizure](symptom)
# - My wife is suffering from [spider bite](symptom) and [retaining fluid](symptom)
# - I have really bad [fever](symptom) and [skin pain](symptom)
# - My wife is suffering from [penile discharge](symptom) and [eye floaters](symptom)
# - My wife is suffering from [abdominal swelling](symptom) and [scrotal swelling](symptom)
# - My husband is suffering from [ear swelling](symptom) and [congestion in chest or lungs](symptom)
# - I'm suffering from [shoulder ache or pain](symptom) and [pain in the ear](symptom)
# - My husband is suffering from [eye redness](symptom) and [snake bite](symptom)
# - My daughter is suffering from [neck ache or pain](symptom) and [heart murmur](symptom)
# - My daughter is suffering from [low heart rate](symptom) and [eye pain](symptom)
# - My daughter is suffering from [itchy rash](symptom), [increased thirst](symptom), and [increased urination](symptom)
# - I don't feel well, I have [confusion](symptom), [confusion and headache](symptom), and [penile discharge](symptom)
# - My wife is suffering from [eye pain](symptom), [mouth swelling](symptom), and [blurry vision](symptom)
# - My wife is suffering from [wrist pain](symptom), [seizure](symptom), and [itchy eyes](symptom)
# - I'm suffering from [steatorrhea](symptom), [vomiting coffee ground material](symptom), and [low back ache or pain](symptom)
# - For the last few days I have had [stomach and abdominal pain](symptom), [general weakness](symptom), and [vaginal itching](symptom)
# - My daughter is suffering from [armpit pain](symptom), [infertility](symptom), and [low blood pressure](symptom)
# - My daughter is suffering from [pelvic pain](symptom), [vaginal pain](symptom), and [hand cut](symptom)
# - I have [failure to thrive](symptom), [tooth pain](symptom), and [pain in the ear](symptom)
# - I have really bad [frequent urination](symptom), [fainting](symptom), and [arm swelling](symptom)
# - My husband is suffering from [shin pain](symptom), [sweating](symptom), and [night sweats](symptom)
# - My husband is suffering from [flatulence](symptom), [hand, finger ache or pain](symptom), and [swelling](symptom)
# - I'm suffering from [groin pain](symptom), [chest pain](symptom), and [foot numbness](symptom)
# - My symptoms are [armpit pain](symptom), [hypothermia](symptom), and [muscle spasm](symptom)
# - My daughter is suffering from [steatorrhea](symptom), [groin pain](symptom), and [confusion](symptom)
# - I don't feel well, I have [suicidal tendencies](symptom), [retaining fluid](symptom), and [bleeding tendency](symptom)
# - My son is suffering from [chest pressure](symptom), [incontinence](symptom), and [dry skin](symptom)
# - My son is suffering from [hand cut](symptom), [foot redness](symptom), and [hair loss](symptom)
# - My wife is suffering from [arm cut](symptom), [swelling of both legs](symptom), and [foot pain](symptom)
# - My symptoms are [hand, finger ache or pain](symptom), [skin sores](symptom), and [obesity](symptom)
# - I have really bad [cranky, crying, fussy, irritable child](symptom), [hot flashes](symptom), and [weight loss, unexplained](symptom)
# - My husband is suffering from [lip swelling](symptom), [tooth pain](symptom), and [hip pain](symptom)
# - I'm suffering from [confusion and headache](symptom), [low heart rate](symptom), and [arm cut](symptom)
# - For the last few days I have had [fainting](symptom), [neck swelling](symptom), and [high blood sugar](symptom)
# - My wife is suffering from [blurry vision](symptom), [learning difficulties](symptom), and [eye swelling](symptom)
# - My symptoms are [increased urination](symptom), [cyanosis](symptom), and [vomiting](symptom)
# - My symptoms are [tired](symptom), [dry skin](symptom), and [increased urination](symptom)
# - My child is suffering from [leg redness](symptom), [choking](symptom), and [hand numbness](symptom)
# - I have [neck ache or pain](symptom), [vaginal discharge](symptom), and [confusion](symptom)
# - My wife is suffering from [cyanosis](symptom), [impotence](symptom), and [retaining fluid](symptom)
# - My symptoms are [foot numbness](symptom), [jaw pain](symptom), and [impotence](symptom)
# - I'm suffering from [facial droop](symptom), [swelling of both legs](symptom), and [wrist pain](symptom)
# - My wife is suffering from [vomiting](symptom), [vomiting](symptom), and [puncture wound](symptom)
# - For the last few days I have had [swollen lymph nodes](symptom), [congestion in chest or lungs](symptom), and [flank pain](symptom)
# - My child is suffering from [chest pressure](symptom), [nipple discharge](symptom), and [learning difficulties](symptom)
# - I don't feel well, I have [incontinence](symptom), [liver failure](symptom), and [rash](symptom)
# - My son is suffering from [bleeding in brain](symptom), [foot numbness](symptom), and [visual problems](symptom)
# - My child is suffering from [limping in a child](symptom), [diarrhea](symptom), and [neck stiffness or tightness](symptom)
# - I have really bad [increased urination](symptom), [failure to thrive](symptom), and [snoring](symptom)
# - My child is suffering from [kidney pain](symptom), [psychiatric problem](symptom), and [diarrhea](symptom)
# - My husband is suffering from [pain or soreness of breast](symptom), [drooling](symptom), and [excessive appetite](symptom)
# - I don't feel well, I have [facial pain](symptom), [jaundice](symptom), and [eye floaters](symptom)
# - My husband is suffering from [sneezing](symptom), [upper leg pain](symptom), and [headache after trauma](symptom)
# - My son is suffering from [penis inflammation or swelling](symptom), [skin swelling](symptom), and [painful rash](symptom)
# - My wife is suffering from [hip pain](symptom), [elbow swelling](symptom), and [penis pain](symptom)
# - I have really bad [skin itching](symptom), [melena](symptom), and [armpit pain](symptom)
# - My son is suffering from [elbow ache or pain](symptom), [ingestion](symptom), and [agitated](symptom)
# - My child is suffering from [urinary retention](symptom), [confusion](symptom), and [hypothermia](symptom)
# - I'm suffering from [impotence](symptom), [blood in vomit](symptom), and [hand itching](symptom)
# - I have really bad [low heart rate](symptom), [foot cut](symptom), and [increased facial hair](symptom)
# - My husband is suffering from [neck swelling](symptom), [infertility](symptom), and [muscle spasm](symptom)
# - I'm suffering from [cyanosis](symptom), [chest burning](symptom), and [painful gums](symptom)
# - I'm suffering from [overdose](symptom), [insomnia](symptom), and [low blood sugar](symptom)
# - I don't feel well, I have [neck swelling](symptom), [increased urination](symptom), and [mouth swelling](symptom)
# - My symptoms are [cranky, crying, fussy, irritable child](symptom), [face numbness](symptom), and [scrotal swelling](symptom)
# - For the last few days I have had [substance abuse](symptom), [eye floaters](symptom), and [traveler's diarrhea](symptom)
# - My husband is suffering from [leg ache or pain](symptom), [hives](symptom), and [visual problems](symptom)
# - I don't feel well, I have [calf swelling](symptom), [hot flashes](symptom), and [general weakness](symptom)
# - My child is suffering from [insect sting](symptom), [sleep disorders](symptom), and [hip pain](symptom)
# - I have really bad [leg ache or pain](symptom), [low blood pressure](symptom), and [mouth swelling](symptom)
# - My daughter is suffering from [cough](symptom), [skin trauma](symptom), and [snake bite](symptom)
# - I have [leg numbness](symptom), [bleeding gums](symptom), and [bleeding gums](symptom)
# - My husband is suffering from [eye floaters](symptom), [swelling](symptom), and [difficulty breathing](symptom)
# - My wife is suffering from [vaginal bleeding after menopause](symptom), [throat pain](symptom), and [increased urination](symptom)
# - I don't feel well, I have [bleeding in brain](symptom), [skin trauma](symptom), and [wrist swelling](symptom)
# - My son is suffering from [wrist pain](symptom), [confusion](symptom), and [blood in urine](symptom)
# - For the last few days I have had [throat pain](symptom), [rectal pain](symptom), and [congestion in chest or lungs](symptom)
# - I have [delusions or hallucinations](symptom), [tooth pain](symptom), and [vomiting coffee ground material](symptom)
# - I have [bleeding tendency](symptom), [memory loss](symptom), and [difficulty breathing](symptom)
# - I have [leg redness](symptom), [vaginal pain](symptom), and [retaining fluid](symptom)
# - My husband is suffering from [shoulder stiffness or tightness](symptom), [back ache or pain](symptom), and [frequent urination](symptom)
# - My symptoms are [mouth pain](symptom), [drooling](symptom), and [head injury](symptom)
# - My wife is suffering from [flank pain](symptom), [hand redness](symptom), and [upper leg pain](symptom)
# - My daughter is suffering from [foot numbness](symptom), [neck stiffness or tightness](symptom), and [diarrhea](symptom)
# - My child is suffering from [hand numbness](symptom), [pain or soreness of breast](symptom), and [calf pain](symptom)
# - My child is suffering from [nipple discharge](symptom), [hand cut](symptom), and [weight loss, unexplained](symptom)
# - I have [bleeding tendency](symptom), [blood in urine](symptom), and [dementia](symptom)
# - I have [dry skin](symptom), [eye pain](symptom), and [painful rash](symptom)
# - My wife is suffering from [pelvic pain](symptom), [shin pain](symptom), and [visual flashing lights](symptom)
# - My son is suffering from [liver failure](symptom), [foot cut](symptom), and [low back ache or pain](symptom)
# - I have [frequent urination](symptom), [leg itching](symptom), and [visual flashing lights](symptom)
# - My child is suffering from [drooping eyelid](symptom), [tremors](symptom), and [hemoptysis](symptom)
# - I have really bad [substance abuse](symptom), [flatulence](symptom), and [confusion](symptom)
# - My husband is suffering from [spider bite](symptom), [puncture wound](symptom), and [overdose](symptom)
# - I have [heat illness](symptom), [frequent urination](symptom), and [ear pressure](symptom)
# - My child is suffering from [foot pain](symptom), [laceration](symptom), and [hoarse voice](symptom)
# - My son is suffering from [skin sores](symptom), [sore throat](symptom), and [eye floaters](symptom)
# - My husband is suffering from [upper leg pain](symptom), [blurry vision](symptom), and [chest burning](symptom)
# - I have [vaginal bleeding after menopause](symptom), [bleeding in brain](symptom), and [dark stools](symptom)
# - My symptoms are [sleep disorders](symptom), [maroon stools](symptom), and [bleeding in brain](symptom)
# - My child is suffering from [cranky, crying, fussy, irritable child](symptom), [jaundice](symptom), and [blister](symptom)
# - My wife is suffering from [toe pain](symptom), [hemoptysis](symptom), and [sneezing](symptom)
# - My symptoms are [upper abdominal pain](symptom), [anger](symptom), and [abdominal swelling](symptom)
# - I'm suffering from [wheezing](symptom), [snoring](symptom), and [heart pulsations and palpitations](symptom)
# - I have [night sweats](symptom), [lethargy](symptom), and [lower abdominal pain](symptom)
# - I'm suffering from [upper leg pain](symptom), [vertigo](symptom), and [bleeding in brain](symptom)
# - My symptoms are [upper leg pain](symptom), [drooling](symptom), and [lump or mass of breast](symptom)
# - I have really bad [vaginal discharge](symptom), [seizure](symptom), and [limping in a child](symptom)
# - My son is suffering from [drooping eyelid](symptom), [hoarse voice](symptom), and [lethargy](symptom)
# - I don't feel well, I have [scrotal swelling](symptom), [dizziness](symptom), and [sleep disorders](symptom)
# - I have really bad [toe pain](symptom), [chest pain](symptom), [ear swelling](symptom), [sleep disorders](symptom)
# - I have [nail injury](symptom), [fever](symptom), [choking](symptom), [seizure](symptom)
# - I don't feel well, I have [vaginal pain](symptom), [lip swelling](symptom), [kidney pain](symptom), [throat pain](symptom)
# - My symptoms are [headache and weakness](symptom), [speech problem](symptom), [ankle pain](symptom), [headache and weakness](symptom)
# - My husband is suffering from [hot skin](symptom), [skin pain](symptom), [swallowing problem](symptom), [rectal pain](symptom)
# - My daughter is suffering from [kidney pain](symptom), [retaining fluid](symptom), [cough](symptom), [fainting](symptom)
# - My symptoms are [head injury](symptom), [dry skin](symptom), [sleep disorders](symptom), [shoulder ache or pain](symptom)
# - I have [heart pulsations and palpitations](symptom), [low heart rate](symptom), [elbow ache or pain](symptom), [armpit pain](symptom)
# - I have really bad [leg cut](symptom), [pain in the ear](symptom), [foot redness](symptom), [anger](symptom)
# - My child is suffering from [blurry vision](symptom), [abscess](symptom), [darkening of the skin](symptom), [arm swelling](symptom)
# - My son is suffering from [melena](symptom), [visual problems](symptom), [hand redness](symptom), [calf swelling](symptom)
# - My daughter is suffering from [snake bite](symptom), [learning difficulties](symptom), [nasal congestion](symptom), [tongue swelling](symptom)
# - For the last few days I have had [lower abdominal pain](symptom), [impotence](symptom), [visual problems](symptom), [psychiatric problem](symptom)
# - I have [skin trauma](symptom), [vaginal bleeding during pregnancy](symptom), [increased thirst](symptom), [obesity](symptom)
# - I'm suffering from [toe pain](symptom), [psychiatric problem](symptom), [tremors](symptom), [jaw pain](symptom)
# - My symptoms are [low back ache or pain](symptom), [painful rash](symptom), [low back ache or pain](symptom), [loss of balance](symptom)
# - I'm suffering from [leg cut](symptom), [blood in vomit](symptom), [melena](symptom), [leg redness](symptom)
# - I have really bad [eye floaters](symptom), [vaginal bleeding](symptom), [suicidal tendencies](symptom), [confusion](symptom)
# - My wife is suffering from [blood in urine](symptom), [spider bite](symptom), [psychiatric problem](symptom), [trauma](symptom)
# - I'm suffering from [jaundice](symptom), [back ache or pain](symptom), [substance abuse](symptom), [insomnia](symptom)
# - For the last few days I have had [tooth pain](symptom), [insect sting](symptom), [skin growths](symptom), [eye pain](symptom)
# - My daughter is suffering from [fever](symptom), [skin growths](symptom), [infertility](symptom), [head injury](symptom)
# - I'm suffering from [arm swelling](symptom), [leg redness](symptom), [ear swelling](symptom), [itchy eyes](symptom)
# - For the last few days I have had [swelling](symptom), [eye pain](symptom), [incontinence](symptom), [arm itching](symptom)
# - I'm suffering from [skin swelling](symptom), [spider bite](symptom), [tremors](symptom), [alcohol abuse](symptom)
# - I have really bad [vaginal bleeding](symptom), [hair loss](symptom), [sweating](symptom), [insomnia](symptom)
# - For the last few days I have had [chest pain](symptom), [abdominal swelling](symptom), [rectal swelling](symptom), [hives](symptom)
# - My son is suffering from [mouth swelling](symptom), [swelling of both legs](symptom), [arm numbness](symptom), [infertility](symptom)
# - For the last few days I have had [liver failure](symptom), [urinary retention](symptom), [weakness](symptom), [hot flashes](symptom)
# - My wife is suffering from [fainting](symptom), [steatorrhea](symptom), [melena](symptom), [painful rash](symptom)
# - I don't feel well, I have [confusion and headache](symptom), [arm cut](symptom), [hot skin](symptom), [swelling of both legs](symptom)
# - For the last few days I have had [tooth pain](symptom), [chest burning](symptom), [loss of balance](symptom), [arm ache or pain](symptom)
# - I have [alcohol abuse](symptom), [facial droop](symptom), [diarrhea](symptom), [scrotal swelling](symptom)
# - My symptoms are [arm cut](symptom), [double vision](symptom), [flank pain](symptom), [jaw pain](symptom)
# - My wife is suffering from [jaundice](symptom), [mouth swelling](symptom), [skin sores](symptom), [lethargy](symptom)
# - My child is suffering from [unusual color or odor of urine](symptom), [liver failure](symptom), [dry skin](symptom), [cyanosis](symptom)
# - I have really bad [swallowing problem](symptom), [arm stiffness or tightness](symptom), [pain in the ear](symptom), [foot numbness](symptom)
# - For the last few days I have had [weakness](symptom), [tired](symptom), [psychiatric problem](symptom), [bleeding gums](symptom)
# - My wife is suffering from [groin pain](symptom), [dry skin](symptom), [unusual color or odor of urine](symptom), [foot cut](symptom)
# - My daughter is suffering from [fever of unknown origin](symptom), [hand itching](symptom), [failure to thrive](symptom), [hemoptysis](symptom)
# - I don't feel well, I have [sore throat](symptom), [chest burning](symptom), [skin infection](symptom), [frequent urination](symptom)
# - My son is suffering from [ankle pain](symptom), [foot itching](symptom), [vaginal discharge](symptom), [blood in urine](symptom)
# - I have [nausea](symptom), [chest pain](symptom), [arm swelling](symptom), [maroon stools](symptom)
# - I'm suffering from [dementia](symptom), [pain or soreness of breast](symptom), [low back ache or pain](symptom), [scrotal swelling](symptom)
# - My daughter is suffering from [stings](symptom), [skin swelling](symptom), [skin pain](symptom), [shin pain](symptom)
# - My daughter is suffering from [hip pain](symptom), [heel pain](symptom), [painful gums](symptom), [flatulence](symptom)
# - I have really bad [skin bumps](symptom), [joint pain](symptom), [blurry vision](symptom), [foot numbness](symptom)
# - My son is suffering from [leg numbness](symptom), [memory loss](symptom), [rectal swelling](symptom), [tremors](symptom)
# - My symptoms are [increased thirst](symptom), [shoulder ache or pain](symptom), [hand, finger ache or pain](symptom), [overdose](symptom)
# - I have really bad [insect sting](symptom), [hives](symptom), [cough](symptom), [ingestion](symptom)
# - I have [blood in vomit](symptom), [rectal swelling](symptom), [difficulty breathing](symptom), [nipple discharge](symptom)
# - I'm suffering from [night sweats](symptom), [unusual color or odor of urine](symptom), [poisoning](symptom), [arm cut](symptom)
# - My child is suffering from [frequent urination](symptom), [rash](symptom), [anger](symptom), [substance abuse](symptom)
# - My husband is suffering from [tongue swelling](symptom), [nasal injury](symptom), [ingestion](symptom), [incontinence](symptom)
# - I have [visual flashing lights](symptom), [visual flashing lights](symptom), [arm ache or pain](symptom), [insomnia](symptom)
# - For the last few days I have had [leg itching](symptom), [limping in a child](symptom), [mouth pain](symptom), [infertility](symptom)
# - I have really bad [general weakness](symptom), [itchy rash](symptom), [facial pain](symptom), [diarrhea](symptom)
# - I'm suffering from [cough](symptom), [skin bumps](symptom), [shortness of breath](symptom), [nail injury](symptom)
# - I have [arm swelling](symptom), [hand cut](symptom), [sinus pain and pressure](symptom), [wrist pain](symptom)
# - I have really bad [nail injury](symptom), [infertility](symptom), [eye swelling](symptom), [low back ache or pain](symptom)
# - I have really bad [heart murmur](symptom), [hurts to breathe](symptom), [lump or mass of breast](symptom), [lump or mass of breast](symptom)
# - I don't feel well, I have [chest pressure](symptom), [drooping eyelid](symptom), [vaginal bleeding during pregnancy](symptom), [chest burning](symptom)
# - My wife is suffering from [pain in the ear](symptom), [impotence](symptom), [jaundice](symptom), [painful urination](symptom)
# - I have [headache](symptom), [nausea](symptom), [chest pain](symptom), [inconsolable baby](symptom)
# - My son is suffering from [chest pain](symptom), [vomiting](symptom), [increased urination](symptom), [heat illness](symptom)
# - My husband is suffering from [swelling of both legs](symptom), [hot flashes](symptom), [urinary retention](symptom), [seizure](symptom)
# - My son is suffering from [neck stiffness or tightness](symptom), [nasal injury](symptom), [vaginal bleeding after menopause](symptom), [hand cut](symptom)
# - My daughter is suffering from [heat illness](symptom), [lump or mass of breast](symptom), [bleeding in brain](symptom), [painful rash](symptom)
# - My wife is suffering from [dark stools](symptom), [wrist swelling](symptom), [calf pain](symptom), [vomiting coffee ground material](symptom)
# - My symptoms are [leg ache or pain](symptom), [neck swelling](symptom), [arm swelling](symptom), [confusion and headache](symptom)
# - My wife is suffering from [arm ache or pain](symptom), [skin trauma](symptom), [overdose](symptom), [calf swelling](symptom)
# - My wife is suffering from [pustule](symptom), [leg redness](symptom), [sweating](symptom), [headache](symptom)
# - My daughter is suffering from [high blood pressure](symptom), [low heart rate](symptom), [facial droop](symptom), [nausea](symptom)
# - My symptoms are [suicidal tendencies](symptom), [skin pain](symptom), [penis pain](symptom), [arm ache or pain](symptom)
# - I'm suffering from [fainting](symptom), [leg numbness](symptom), [discharge from ear](symptom), [blurry vision](symptom)
# - My wife is suffering from [scrotal pain](symptom), [substance abuse](symptom), [rectal pain](symptom), [leg numbness](symptom)
# - My daughter is suffering from [vaginal pain](symptom), [wrist pain](symptom), [back ache or pain](symptom), [foot redness](symptom)
# - My child is suffering from [excessive appetite](symptom), [cyanosis](symptom), [cyanosis](symptom), [excessive appetite](symptom)
# - I have really bad [scrotal pain](symptom), [nasal injury](symptom), [learning difficulties](symptom), [arm ache or pain](symptom)
# - My daughter is suffering from [depressed](symptom), [headache and weakness](symptom), [cyanosis](symptom), [hair loss](symptom)
# - My son is suffering from [toe pain](symptom), [trauma](symptom), [fainting](symptom), [skin pain](symptom)
# - My child is suffering from [nail injury](symptom), [pain in the ear](symptom), [pustule](symptom), [foot redness](symptom)
# - My husband is suffering from [chills](symptom), [behavioral problem](symptom), [vomiting coffee ground material](symptom), [lower abdominal pain](symptom)
# - I don't feel well, I have [diarrhea](symptom), [back ache or pain](symptom), [groin pain](symptom), [swallowing problem](symptom)
# - I have [toe pain](symptom), [learning difficulties](symptom), [constipation](symptom), [fever in the returning traveler](symptom)
# - My husband is suffering from [jaundice](symptom), [painful urination](symptom), [weight loss, unexplained](symptom), [pustule](symptom)
# - My husband is suffering from [infertility](symptom), [sleep disorders](symptom), [nipple discharge](symptom), [eye redness](symptom)
# - I have [increased facial hair](symptom), [painful gums](symptom), [fainting](symptom), [headache](symptom)
# - I have really bad [elbow swelling](symptom), [memory loss](symptom), [blurry vision](symptom), [flank pain](symptom)
# - I have [eye floaters](symptom), [hurts to breathe](symptom), [anger](symptom), [cough](symptom)
# - My son is suffering from [lump or mass of breast](symptom), [dark stools](symptom), [low heart rate](symptom), [pain or soreness of breast](symptom)
# - My child is suffering from [knee pain](symptom), [change in behavior](symptom), [nasal injury](symptom), [groin pain](symptom)
# - I'm suffering from [upper leg pain](symptom), [bleeding tendency](symptom), [eye floaters](symptom), [pregnancy problem](symptom)
# - My wife is suffering from [leg ache or pain](symptom), [arm numbness](symptom), [hand itching](symptom), [headache](symptom)
# - My symptoms are [throat pain](symptom), [headache](symptom), [shortness of breath](symptom), [dry skin](symptom)
# - I don't feel well, I have [anger](symptom), [sleep disorders](symptom), [pustule](symptom), [increased thirst](symptom)
# - My child is suffering from [penis pain](symptom), [anger](symptom), [throat pain](symptom), [vaginal bleeding](symptom)
# - I don't feel well, I have [skin trauma](symptom), [hot skin](symptom), [penile discharge](symptom), [leg numbness](symptom)
# - My child is suffering from [suicidal tendencies](symptom), [foot redness](symptom), [skin itching](symptom), [neck ache or pain](symptom)
# - I'm suffering from [shoulder ache or pain](symptom), [shoulder stiffness or tightness](symptom), [facial droop](symptom), [seizure](symptom)
