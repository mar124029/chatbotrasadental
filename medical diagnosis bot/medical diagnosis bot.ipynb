# %% [markdown]
# ### Part1 :
# ### Prepare input data for diagnosis portion

# %%
import pandas as pd
import spacy
import random
import re
# Out:
# 2023-06-02 12:19:10.297246: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-02 12:19:10.418159: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-02 12:19:10.419361: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-02 12:19:11.241922: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
nlp = spacy.load('en_core_web_md')

# %%
def get_sentence_vectors(text, nlp):
    
    # get tokens for each word in a sentence
    embedding = nlp(text).vector.tolist()
    
    return embedding

# %% [markdown]
# Import and merge data

# %%
illness_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/dia_t.csv')
symptom_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/sym_t.csv')
links_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/diffsydiw.csv')

# %%
illness_df.head()
# Out:
#    did                                           diagnose
# 0    1  Abdominal aortic aneurysm
# (enlarged major bloo...
# 1    2                                 Abdominal swelling
# 2    3                                   Abdominal trauma
# 3    4                               Abrasions
#  (scrapes)
# 4    5  ACE inhibitor induced cough
# blood pressure med...

# %%
symptom_df.head()
# Out:
#    syd                      symptom
# 0    1         Upper abdominal pain
# 1    2         Lower abdominal pain
# 2    3  Abscess (Collection of pus)
# 3    4                Alcohol abuse
# 4    5        Anxiety (Nervousness)

# %%
source_data = (links_df
               .merge(illness_df, on="did")
               .merge(symptom_df, on="syd"))
source_data
# Out:
#         syd     did  wei                                           diagnose  \
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
source_data
# Out:
#         syd     did  wei                                           diagnose  \
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
# Remove missing data and select columns we needed

source_data = source_data.loc[~(source_data['symptom'].isna()) & ~(source_data['diagnose'].isna()),['did', 'syd', 'diagnose', 'symptom']]

source_data.columns = ['illness_id', 'symptom_id', 'illness', 'symptom']

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis
# inflammation of the gallbladder
# 1                Choledocholithiasis
# stone in bile duct
# 2                             Cholelithiasis
# gallstones
# 3                                          Constipation
# 4                           Gastric ulcer
# stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564                                 Hair loss
# alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %%
# tidy up some new messy characters
source_data['illness'] = source_data['illness'].str.replace('\x0b', ' ')
source_data['symptom'] = source_data['symptom'].str.replace('\x0b', ' ')

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis inflammation of the gallbladder
# 1                Choledocholithiasis stone in bile duct
# 2                             Cholelithiasis gallstones
# 3                                          Constipation
# 4                           Gastric ulcer stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma skin cancer on ...
# 5564                                 Hair loss alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %% [markdown]
# Use our function to convert each symptom to a vector representation we can then save our symptom data down to the data folder

# %%
symptom_df = symptom_df.loc[~symptom_df['symptom'].isna()]

symptom_df['embedding'] = symptom_df.apply(lambda row: get_sentence_vectors(row['symptom'], nlp), axis=1)
# symptom_df.columns = ['symptom_id', 'symptom', 'symptom_vector']

# %%
symptom_df
# Out:
#      syd                          symptom  \
# 0      1             Upper abdominal pain
# 1      2             Lower abdominal pain
# 2      3      Abscess (Collection of pus)
# 3      4                    Alcohol abuse
# 4      5            Anxiety (Nervousness)
# ..   ...                              ...
# 267  295                 Nipple discharge
# 268  301  Shoulder stiffness or tightness
# 269  303       Arm stiffness or tightness
# 270  304              High blood pressure
# 271  306                 High blood sugar
#
#                                              embedding
# 0    [-0.3931533396244049, -1.122189998626709, -2.3...
# 1    [0.11224666982889175, -1.3984565734863281, -2....
# 2    [-4.394866943359375, -5.325353145599365, 3.294...
# 3    [-1.0100150108337402, -3.2876999378204346, -1....
# 4    [-2.1256749629974365, -4.137800216674805, 4.55...
# ..                                                 ...
# 267  [-1.7614949941635132, 0.5206300020217896, -1.9...
# 268  [-1.2457798719406128, 2.181957483291626, -6.26...
# 269  [-1.7361524105072021, 1.2958674430847168, -4.8...
# 270  [-0.959559977054596, 0.45383667945861816, -2.6...
# 271  [-0.032566625624895096, -1.4907633066177368, -...
#
# [246 rows x 3 columns]

# %%
# remove messy charecters

symptom_df['symptom'] = symptom_df['symptom'].str.replace('\x0b', ' ')

# %%
source_data.to_pickle('input_data/source_data.pkl')
symptom_df.to_pickle('input_data/symptoms.pkl')

# %% [markdown]
# ### Create a vector of symtpoms for each illness described in the data

# %% [markdown]
# Here we will loop through each illness described in the dataset
# and flag (with a 1 or 0) each of the symptoms of that illness.
# We will do then compare a list of flagged symptoms described by
# the user to this using a cosine similarity function to diagnose
# a potential illness.

# %%
# list of illness 
illnesses = list(source_data['illness'].drop_duplicates())

# list we will use store our illness vectors 
symptom_vectors = []

for illness in illnesses:
    
    illnesses_symptoms = list(source_data.loc[source_data['illness'] == illness, 'symptom'].drop_duplicates())
    
    symptom_df['related_to_illness'] = 0
    symptom_df.loc[symptom_df['symptom'].isin(illnesses_symptoms), "related_to_illness"] = 1
    
    symptom_vectors.append(list(symptom_df["related_to_illness"]))
    
diagnosis_data = pd.DataFrame({"illness":illnesses,
                                "illness_vector":symptom_vectors})

# %%
diagnosis_data.to_pickle("data/diagnosis_data.pkl")

# %% [markdown]
# ### Part 2:
# ### Generate training samples with flagged entities

# %% [markdown]
# In this part we will attempt to generate some training examples for the NLU model to understand how our users will describe symtoms to the chat bot. To do this we simply loop through our symptoms, sometimes combining them before appending them to different beginnings/endings.
#
# We also make sure to tag any symptom describtions as a symptom entity, which will be understood by Rasa's NLU model. You can see this is accomplished by inserting '(symptom)' beside any mention of symptoms.
#
# The output of this is inserted into nlu.md within the main project.

# %%
number_of_symtoms = [1, 2, 3, 4]
start_of_description = [
    "I have",
    "I'm suffering from",
    "I have really bad",
    "My symptoms are",
    "For the last few days I have had",
    "My husband is suffering from" ,
    "My wife is suffering from",
    "My son is suffering from",
    "My daughter is suffering from",
    "My child is suffering from",
    "I don't feel well, I have"
]

# Get some examples of users describing different number of symtoms 

for symptoms_count in number_of_symtoms:
    
    # make 100 example of each number of symtoms 
    for ex in range(1, 101):
        
        description_beginning = random.choice(start_of_description)
        
        # collect some random symtoms 
        symptom_1 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_2 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_3 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_4 = symptom_df['symptom'].sample(1).iloc[0].lower()
        
        symptoms = [symptom_1, symptom_2, symptom_3, symptom_4]
        symptom_entity = []
        
        # Remove paranthases from symptoms and add nessecary entity tags to symtoms 
        for symptom in symptoms:
            symptom = re.sub(r"\([^)]+\)", "", symptom).strip()
            symptom = f"[{symptom}](symptom)"
            symptom_entity.append(symptom)
            
        symptom_1 = symptom_entity[0]
        symptom_2 = symptom_entity[1]
        symptom_3 = symptom_entity[2]
        symptom_4 = symptom_entity[3]
        
        # Create the training sample strig 
        
        if symptoms_count == 1:
            
            symptom_string = f"- {description_beginning} {symptom_1}"
            
        if symptoms_count == 2:
            
            symptom_string = f"- {description_beginning} {symptom_1} and {symptom_2}"
            
        if symptoms_count == 3:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, and {symptom_3}"
            
        if symptoms_count == 4:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, {symptom_3}, {symptom_4}"
        
        print(symptom_string)
# Out:
# - My husband is suffering from [itchy rash](symptom)
# - My wife is suffering from [low heart rate](symptom)
# - I'm suffering from [foot swelling](symptom)
# - My husband is suffering from [jaundice](symptom)
# - I have really bad [arm ache or pain](symptom)
# - My wife is suffering from [hip pain](symptom)
# - My symptoms are [anxiety](symptom)
# - For the last few days I have had [liver failure](symptom)
# - I have [nasal bleeding](symptom)
# - I have really bad [hip pain](symptom)
# - I have really bad [diarrhea](symptom)
# - My husband is suffering from [joint stiffness](symptom)
# - My wife is suffering from [bleeding tendency](symptom)
# - My daughter is suffering from [neck stiffness or tightness](symptom)
# - I'm suffering from [bleeding in brain](symptom)
# - I have [memory loss](symptom)
# - My symptoms are [blister](symptom)
# - I have really bad [groin pain](symptom)
# - My daughter is suffering from [insomnia](symptom)
# - My child is suffering from [bleeding in brain](symptom)
# - I'm suffering from [leg ache or pain](symptom)
# - I'm suffering from [hand cut](symptom)
# - I have really bad [visual flashing lights](symptom)
# - My child is suffering from [scrotal pain](symptom)
# - For the last few days I have had [pustule](symptom)
# - I don't feel well, I have [nipple discharge](symptom)
# - My symptoms are [difficulty breathing](symptom)
# - My symptoms are [choking](symptom)
# - I don't feel well, I have [blurry vision](symptom)
# - I'm suffering from [vomiting coffee ground material](symptom)
# - My symptoms are [swelling](symptom)
# - I have [heel pain](symptom)
# - I have [vaginal bleeding](symptom)
# - My symptoms are [choking](symptom)
# - I have [pregnancy problem](symptom)
# - I have really bad [fever in the returning traveler](symptom)
# - For the last few days I have had [mouth swelling](symptom)
# - My symptoms are [swelling of both legs](symptom)
# - I don't feel well, I have [vaginal bleeding](symptom)
# - My wife is suffering from [skin trauma](symptom)
# - My son is suffering from [sneezing](symptom)
# - My symptoms are [foot pain](symptom)
# - My wife is suffering from [limping in a child](symptom)
# - My son is suffering from [painful urination](symptom)
# - My wife is suffering from [leg ache or pain](symptom)
# - I have really bad [foot swelling](symptom)
# - My husband is suffering from [hemoptysis](symptom)
# - For the last few days I have had [arm stiffness or tightness](symptom)
# - I'm suffering from [blister](symptom)
# - My husband is suffering from [vaginal bleeding](symptom)
# - I have [congestion in chest or lungs](symptom)
# - I don't feel well, I have [mouth ulcers](symptom)
# - I have really bad [impotence](symptom)
# - My child is suffering from [vaginal pain](symptom)
# - My wife is suffering from [melena](symptom)
# - My symptoms are [pregnancy problem](symptom)
# - I have [mouth ulcers](symptom)
# - I have really bad [anxiety](symptom)
# - For the last few days I have had [rash](symptom)
# - My child is suffering from [dark stools](symptom)
# - My son is suffering from [stomach and abdominal pain](symptom)
# - My daughter is suffering from [penis pain](symptom)
# - My wife is suffering from [amenorrhea](symptom)
# - My husband is suffering from [loss of balance](symptom)
# - My husband is suffering from [dementia](symptom)
# - I don't feel well, I have [calf pain](symptom)
# - I'm suffering from [snoring](symptom)
# - My husband is suffering from [visual problems](symptom)
# - I have [high blood pressure](symptom)
# - My son is suffering from [facial droop](symptom)
# - My daughter is suffering from [painful rash](symptom)
# - My symptoms are [abdominal swelling](symptom)
# - My child is suffering from [snoring](symptom)
# - My husband is suffering from [nasal bleeding](symptom)
# - For the last few days I have had [hives](symptom)
# - My son is suffering from [pain or soreness of breast](symptom)
# - My daughter is suffering from [fever of unknown origin](symptom)
# - I have [penis inflammation or swelling](symptom)
# - My son is suffering from [armpit pain](symptom)
# - I'm suffering from [calf pain](symptom)
# - For the last few days I have had [ear pressure](symptom)
# - I don't feel well, I have [scrotal pain](symptom)
# - My symptoms are [tremors](symptom)
# - I have [confusion](symptom)
# - I'm suffering from [psychiatric problem](symptom)
# - My wife is suffering from [discharge from ear](symptom)
# - I'm suffering from [confusion](symptom)
# - My child is suffering from [swelling of both legs](symptom)
# - My daughter is suffering from [nasal injury](symptom)
# - I'm suffering from [tongue swelling](symptom)
# - I don't feel well, I have [heel pain](symptom)
# - My wife is suffering from [elbow swelling](symptom)
# - My husband is suffering from [retaining fluid](symptom)
# - My symptoms are [bleeding in brain](symptom)
# - For the last few days I have had [upper abdominal pain](symptom)
# - My symptoms are [hand redness](symptom)
# - For the last few days I have had [arm stiffness or tightness](symptom)
# - My son is suffering from [failure to thrive](symptom)
# - My daughter is suffering from [back ache or pain](symptom)
# - I'm suffering from [nausea](symptom)
# - My wife is suffering from [leg itching](symptom) and [numbness](symptom)
# - My husband is suffering from [sleep disorders](symptom) and [flank pain](symptom)
# - I'm suffering from [obesity](symptom) and [mouth ulcers](symptom)
# - My child is suffering from [steatorrhea](symptom) and [choking](symptom)
# - My son is suffering from [ear swelling](symptom) and [failure to thrive](symptom)
# - My husband is suffering from [trauma](symptom) and [toe pain](symptom)
# - I'm suffering from [lump or mass of breast](symptom) and [neck ache or pain](symptom)
# - My daughter is suffering from [blurry vision](symptom) and [fever](symptom)
# - I have really bad [low blood pressure](symptom) and [wrist pain](symptom)
# - For the last few days I have had [skin infection](symptom) and [dizziness](symptom)
# - My daughter is suffering from [cranky, crying, fussy, irritable child](symptom) and [limping in a child](symptom)
# - My husband is suffering from [scrotal swelling](symptom) and [foot cut](symptom)
# - My son is suffering from [skin trauma](symptom) and [liver failure](symptom)
# - I'm suffering from [shoulder stiffness or tightness](symptom) and [unsteady gait](symptom)
# - My son is suffering from [drooping eyelid](symptom) and [elbow ache or pain](symptom)
# - I'm suffering from [hand, finger ache or pain](symptom) and [blood in vomit](symptom)
# - My child is suffering from [mouth swelling](symptom) and [chest burning](symptom)
# - I have [arm numbness](symptom) and [excessive appetite](symptom)
# - I have really bad [blood in vomit](symptom) and [wrist pain](symptom)
# - My symptoms are [skin pain](symptom) and [failure to thrive](symptom)
# - My husband is suffering from [neck stiffness or tightness](symptom) and [headache and weakness](symptom)
# - My husband is suffering from [sleep disorders](symptom) and [foot pain](symptom)
# - My son is suffering from [pain in the ear](symptom) and [increased urination](symptom)
# - My husband is suffering from [cough](symptom) and [congestion in chest or lungs](symptom)
# - My daughter is suffering from [back ache or pain](symptom) and [eye redness](symptom)
# - I'm suffering from [stings](symptom) and [joint pain](symptom)
# - For the last few days I have had [penile discharge](symptom) and [penis inflammation or swelling](symptom)
# - I'm suffering from [confusion](symptom) and [calf swelling](symptom)
# - I don't feel well, I have [memory loss](symptom) and [wheezing](symptom)
# - My daughter is suffering from [heat illness](symptom) and [cyanosis](symptom)
# - My symptoms are [laceration](symptom) and [fever](symptom)
# - My symptoms are [vertigo](symptom) and [learning difficulties](symptom)
# - My husband is suffering from [stomach and abdominal pain](symptom) and [headache and weakness](symptom)
# - My child is suffering from [sleep disorders](symptom) and [sore throat](symptom)
# - I have [ankle pain](symptom) and [swelling of both legs](symptom)
# - My son is suffering from [elbow swelling](symptom) and [facial pain](symptom)
# - I have [fainting](symptom) and [impotence](symptom)
# - I'm suffering from [bleeding in brain](symptom) and [urinary retention](symptom)
# - I have really bad [tremors](symptom) and [ear swelling](symptom)
# - My symptoms are [snoring](symptom) and [muscle spasm](symptom)
# - My daughter is suffering from [leg ache or pain](symptom) and [blood in vomit](symptom)
# - I'm suffering from [trauma](symptom) and [hair loss](symptom)
# - I don't feel well, I have [ear pressure](symptom) and [hemoptysis](symptom)
# - My wife is suffering from [vaginal bleeding](symptom) and [blurry vision](symptom)
# - I have [lip swelling](symptom) and [vaginal bleeding during pregnancy](symptom)
# - I have really bad [swelling](symptom) and [drooping eyelid](symptom)
# - For the last few days I have had [ear pressure](symptom) and [arm swelling](symptom)
# - I don't feel well, I have [foot swelling](symptom) and [dizziness](symptom)
# - I'm suffering from [headache and weakness](symptom) and [penis inflammation or swelling](symptom)
# - My husband is suffering from [muscle pain](symptom) and [poisoning](symptom)
# - My husband is suffering from [substance abuse](symptom) and [muscle spasm](symptom)
# - I don't feel well, I have [painful gums](symptom) and [maroon stools](symptom)
# - For the last few days I have had [wheezing](symptom) and [tired](symptom)
# - My son is suffering from [hypothermia](symptom) and [shin pain](symptom)
# - I'm suffering from [arm swelling](symptom) and [shoulder ache or pain](symptom)
# - My symptoms are [elbow ache or pain](symptom) and [penis inflammation or swelling](symptom)
# - I'm suffering from [skin pain](symptom) and [speech problem](symptom)
# - I have [joint pain](symptom) and [increased facial hair](symptom)
# - My husband is suffering from [nasal bleeding](symptom) and [agitated](symptom)
# - I'm suffering from [upper abdominal pain](symptom) and [general weakness](symptom)
# - I have really bad [abscess](symptom) and [pustule](symptom)
# - I'm suffering from [limping in a child](symptom) and [shin pain](symptom)
# - I'm suffering from [behavioral problem](symptom) and [increased urination](symptom)
# - My daughter is suffering from [stomach and abdominal pain](symptom) and [muscle pain](symptom)
# - My son is suffering from [hand, finger ache or pain](symptom) and [dark stools](symptom)
# - My husband is suffering from [suicidal tendencies](symptom) and [blood in vomit](symptom)
# - I have really bad [skin growths](symptom) and [snoring](symptom)
# - I have really bad [increased urination](symptom) and [foot pain](symptom)
# - My child is suffering from [depressed](symptom) and [back ache or pain](symptom)
# - I have [pain or soreness of breast](symptom) and [hand numbness](symptom)
# - My wife is suffering from [swallowing problem](symptom) and [facial droop](symptom)
# - My daughter is suffering from [chest pain](symptom) and [suicidal tendencies](symptom)
# - My child is suffering from [arm itching](symptom) and [heat illness](symptom)
# - I have really bad [stings](symptom) and [seizure](symptom)
# - My wife is suffering from [impotence](symptom) and [congestion in chest or lungs](symptom)
# - For the last few days I have had [rectal pain](symptom) and [low blood sugar](symptom)
# - For the last few days I have had [hand redness](symptom) and [flatulence](symptom)
# - My child is suffering from [itchy eyes](symptom) and [amenorrhea](symptom)
# - My wife is suffering from [facial droop](symptom) and [muscle pain](symptom)
# - My son is suffering from [elbow ache or pain](symptom) and [insomnia](symptom)
# - My husband is suffering from [hemoptysis](symptom) and [amenorrhea](symptom)
# - My daughter is suffering from [hair loss](symptom) and [confusion and headache](symptom)
# - My husband is suffering from [neck stiffness or tightness](symptom) and [hand, finger ache or pain](symptom)
# - I don't feel well, I have [limping in a child](symptom) and [suicidal tendencies](symptom)
# - I'm suffering from [pustule](symptom) and [eye swelling](symptom)
# - My son is suffering from [wheezing](symptom) and [eye floaters](symptom)
# - I have [trauma](symptom) and [sweating](symptom)
# - My son is suffering from [throat pain](symptom) and [nipple discharge](symptom)
# - For the last few days I have had [swallowing problem](symptom) and [neck stiffness or tightness](symptom)
# - I have [trauma](symptom) and [nasal bleeding](symptom)
# - I have really bad [hand, finger ache or pain](symptom) and [sore throat](symptom)
# - For the last few days I have had [lump or mass of breast](symptom) and [pulling at ears](symptom)
# - I have [foot cut](symptom) and [flank pain](symptom)
# - I'm suffering from [sinus pain and pressure](symptom) and [chills](symptom)
# - My daughter is suffering from [overdose](symptom) and [anger](symptom)
# - My daughter is suffering from [vaginal bleeding after menopause](symptom) and [painful rash](symptom)
# - My child is suffering from [insomnia](symptom) and [jaw pain](symptom)
# - My symptoms are [heel pain](symptom) and [cyanosis](symptom)
# - My son is suffering from [wrist pain](symptom) and [anger](symptom)
# - For the last few days I have had [swollen gums](symptom) and [limping in a child](symptom)
# - I don't feel well, I have [vaginal bleeding during pregnancy](symptom), [blister](symptom), and [nasal congestion](symptom)
# - My wife is suffering from [vaginal discharge](symptom), [hand redness](symptom), and [throat pain](symptom)
# - My son is suffering from [retaining fluid](symptom), [lower abdominal pain](symptom), and [low back ache or pain](symptom)
# - My daughter is suffering from [bleeding gums](symptom), [mouth swelling](symptom), and [fever](symptom)
# - I have [hand itching](symptom), [vaginal discharge](symptom), and [substance abuse](symptom)
# - My husband is suffering from [jaundice](symptom), [leg itching](symptom), and [tongue swelling](symptom)
# - My wife is suffering from [visual flashing lights](symptom), [overdose](symptom), and [difficulty breathing](symptom)
# - My son is suffering from [high blood sugar](symptom), [steatorrhea](symptom), and [arm swelling](symptom)
# - I have [shin pain](symptom), [abdominal swelling](symptom), and [painful rash](symptom)
# - My son is suffering from [behavioral problem](symptom), [skin itching](symptom), and [depressed](symptom)
# - I have really bad [joint stiffness](symptom), [cyanosis](symptom), and [increased thirst](symptom)
# - I have [confusion and headache](symptom), [hot flashes](symptom), and [leg cut](symptom)
# - I have really bad [vaginal bleeding](symptom), [sneezing](symptom), and [substance abuse](symptom)
# - My wife is suffering from [heat illness](symptom), [skin itching](symptom), and [hair loss](symptom)
# - I don't feel well, I have [dizziness](symptom), [wrist swelling](symptom), and [arm ache or pain](symptom)
# - My wife is suffering from [heat illness](symptom), [heart murmur](symptom), and [hot flashes](symptom)
# - My son is suffering from [frequent urination](symptom), [snake bite](symptom), and [muscle spasm](symptom)
# - I have [neck swelling](symptom), [scrotal pain](symptom), and [choking](symptom)
# - I'm suffering from [arm redness](symptom), [dizziness](symptom), and [painful rash](symptom)
# - My wife is suffering from [shin pain](symptom), [penile discharge](symptom), and [double vision](symptom)
# - My wife is suffering from [hypothermia](symptom), [arm itching](symptom), and [failure to thrive](symptom)
# - My son is suffering from [arm stiffness or tightness](symptom), [ear swelling](symptom), and [hand redness](symptom)
# - My son is suffering from [insomnia](symptom), [back ache or pain](symptom), and [eye pain](symptom)
# - My husband is suffering from [ringing in ears](symptom), [urinary retention](symptom), and [neck swelling](symptom)
# - For the last few days I have had [difficulty breathing](symptom), [jaundice](symptom), and [general weakness](symptom)
# - I have really bad [facial droop](symptom), [facial pain](symptom), and [arm stiffness or tightness](symptom)
# - My wife is suffering from [cough](symptom), [neck ache or pain](symptom), and [hot skin](symptom)
# - My symptoms are [eye redness](symptom), [speech problem](symptom), and [dementia](symptom)
# - I'm suffering from [pain in the ear](symptom), [vaginal bleeding](symptom), and [swallowing problem](symptom)
# - For the last few days I have had [fever of unknown origin](symptom), [darkening of the skin](symptom), and [lump or mass of breast](symptom)
# - I have [headache and weakness](symptom), [foot pain](symptom), and [calf pain](symptom)
# - I'm suffering from [scrotal pain](symptom), [trauma](symptom), and [puncture wound](symptom)
# - My son is suffering from [suicidal tendencies](symptom), [eye pain](symptom), and [dizziness](symptom)
# - I'm suffering from [facial pain](symptom), [obesity](symptom), and [sneezing](symptom)
# - My wife is suffering from [leg itching](symptom), [weight loss, unexplained](symptom), and [trauma](symptom)
# - I have [diarrhea](symptom), [hair loss](symptom), and [arm cut](symptom)
# - My symptoms are [rectal pain](symptom), [foot redness](symptom), and [vomiting](symptom)
# - I don't feel well, I have [pain or soreness of breast](symptom), [high blood sugar](symptom), and [foot cut](symptom)
# - My daughter is suffering from [vaginal bleeding during pregnancy](symptom), [psychiatric problem](symptom), and [visual problems](symptom)
# - My husband is suffering from [tremors](symptom), [foot cut](symptom), and [blood in vomit](symptom)
# - My husband is suffering from [unusual color or odor of urine](symptom), [drooling](symptom), and [kidney pain](symptom)
# - My son is suffering from [muscle spasm](symptom), [lethargy](symptom), and [low blood pressure](symptom)
# - I don't feel well, I have [vomiting coffee ground material](symptom), [wrist pain](symptom), and [speech problem](symptom)
# - I have really bad [sinus pain and pressure](symptom), [painful gums](symptom), and [jaw pain](symptom)
# - My son is suffering from [joint stiffness](symptom), [hand numbness](symptom), and [nausea](symptom)
# - My wife is suffering from [bloody diarrhea](symptom), [lethargy](symptom), and [abdominal swelling](symptom)
# - My husband is suffering from [groin pain](symptom), [scrotal swelling](symptom), and [lethargy](symptom)
# - My child is suffering from [painful rash](symptom), [cranky, crying, fussy, irritable child](symptom), and [bleeding gums](symptom)
# - My daughter is suffering from [cyanosis](symptom), [hand redness](symptom), and [weight loss, unexplained](symptom)
# - I don't feel well, I have [hives](symptom), [heart murmur](symptom), and [sneezing](symptom)
# - For the last few days I have had [visual flashing lights](symptom), [sneezing](symptom), and [drooping eyelid](symptom)
# - My child is suffering from [hand redness](symptom), [nasal congestion](symptom), and [kidney pain](symptom)
# - I have really bad [skin bumps](symptom), [flank pain](symptom), and [muscle pain](symptom)
# - My wife is suffering from [leg redness](symptom), [traveler's diarrhea](symptom), and [vaginal pain](symptom)
# - For the last few days I have had [painful urination](symptom), [nausea](symptom), and [swelling of both legs](symptom)
# - My daughter is suffering from [increased urination](symptom), [traveler's diarrhea](symptom), and [face numbness](symptom)
# - My husband is suffering from [liver failure](symptom), [excessive appetite](symptom), and [weakness](symptom)
# - I don't feel well, I have [overdose](symptom), [elbow ache or pain](symptom), and [neck stiffness or tightness](symptom)
# - My husband is suffering from [heart pulsations and palpitations](symptom), [wrist swelling](symptom), and [vomiting coffee ground material](symptom)
# - For the last few days I have had [knee pain](symptom), [seizure](symptom), and [elbow swelling](symptom)
# - My daughter is suffering from [pelvic pain](symptom), [impotence](symptom), and [bleeding tendency](symptom)
# - My wife is suffering from [mouth swelling](symptom), [lip swelling](symptom), and [excessive appetite](symptom)
# - My symptoms are [elbow ache or pain](symptom), [hip pain](symptom), and [vaginal discharge](symptom)
# - My husband is suffering from [constipation](symptom), [low back ache or pain](symptom), and [skin infection](symptom)
# - My symptoms are [nasal congestion](symptom), [mouth ulcers](symptom), and [weakness](symptom)
# - I have [unusual color or odor of urine](symptom), [low back ache or pain](symptom), and [darkening of the skin](symptom)
# - My husband is suffering from [suicidal tendencies](symptom), [eye redness](symptom), and [liver failure](symptom)
# - I'm suffering from [vertigo](symptom), [headache after trauma](symptom), and [sneezing](symptom)
# - My son is suffering from [congestion in chest or lungs](symptom), [change in behavior](symptom), and [behavioral problem](symptom)
# - I'm suffering from [sinus pain and pressure](symptom), [hurts to breathe](symptom), and [behavioral problem](symptom)
# - My symptoms are [stomach and abdominal pain](symptom), [anger](symptom), and [hand cut](symptom)
# - My husband is suffering from [inconsolable baby](symptom), [chest pain](symptom), and [visual flashing lights](symptom)
# - My daughter is suffering from [psychiatric problem](symptom), [skin infection](symptom), and [psychiatric problem](symptom)
# - My wife is suffering from [ankle pain](symptom), [fever](symptom), and [calf pain](symptom)
# - My child is suffering from [lip swelling](symptom), [trauma](symptom), and [leg cut](symptom)
# - For the last few days I have had [vaginal pain](symptom), [sinus pain and pressure](symptom), and [ankle pain](symptom)
# - For the last few days I have had [bleeding in brain](symptom), [vaginal bleeding after menopause](symptom), and [jaundice](symptom)
# - My husband is suffering from [frequent urination](symptom), [frequent urination](symptom), and [increased thirst](symptom)
# - My son is suffering from [blurry vision](symptom), [drooling](symptom), and [numbness](symptom)
# - My symptoms are [shin pain](symptom), [skin trauma](symptom), and [retaining fluid](symptom)
# - I don't feel well, I have [knee pain](symptom), [hives](symptom), and [urinary retention](symptom)
# - My son is suffering from [abdominal swelling](symptom), [vaginal itching](symptom), and [lip swelling](symptom)
# - I have really bad [chest pain](symptom), [scrotal swelling](symptom), and [arm stiffness or tightness](symptom)
# - My child is suffering from [arm numbness](symptom), [general weakness](symptom), and [weight loss, unexplained](symptom)
# - My daughter is suffering from [increased thirst](symptom), [calf swelling](symptom), and [kidney pain](symptom)
# - I don't feel well, I have [itchy eyes](symptom), [elbow ache or pain](symptom), and [insect sting](symptom)
# - I'm suffering from [seizure](symptom), [vaginal bleeding during pregnancy](symptom), and [lump or mass of breast](symptom)
# - My husband is suffering from [tooth pain](symptom), [hurts to breathe](symptom), and [face numbness](symptom)
# - My symptoms are [eye pain](symptom), [darkening of the skin](symptom), and [ankle pain](symptom)
# - My daughter is suffering from [hot skin](symptom), [mouth swelling](symptom), and [pelvic pain](symptom)
# - My wife is suffering from [scrotal pain](symptom), [fever of unknown origin](symptom), and [dark stools](symptom)
# - I have [toe pain](symptom), [hemoptysis](symptom), and [dementia](symptom)
# - My child is suffering from [chest pain](symptom), [dark stools](symptom), and [heat illness](symptom)
# - My symptoms are [drooling](symptom), [anxiety](symptom), and [vomiting](symptom)
# - My symptoms are [bloody diarrhea](symptom), [lip swelling](symptom), and [nasal injury](symptom)
# - I'm suffering from [hurts to breathe](symptom), [nasal injury](symptom), and [rash](symptom)
# - I don't feel well, I have [scrotal pain](symptom), [rectal pain](symptom), and [vaginal bleeding during pregnancy](symptom)
# - I have really bad [neck ache or pain](symptom), [ankle pain](symptom), and [visual flashing lights](symptom)
# - For the last few days I have had [headache after trauma](symptom), [blister](symptom), and [steatorrhea](symptom)
# - I have [ringing in ears](symptom), [high blood pressure](symptom), and [lump or mass of breast](symptom)
# - I have [obesity](symptom), [pregnancy problem](symptom), [neck stiffness or tightness](symptom), [seizure](symptom)
# - My husband is suffering from [frequent urination](symptom), [seizure](symptom), [lip swelling](symptom), [blurry vision](symptom)
# - I don't feel well, I have [lower abdominal pain](symptom), [pulling at ears](symptom), [tongue swelling](symptom), [ingestion](symptom)
# - My son is suffering from [foot numbness](symptom), [arm numbness](symptom), [urinary retention](symptom), [shin pain](symptom)
# - My wife is suffering from [shin pain](symptom), [leg cut](symptom), [unusual color or odor of urine](symptom), [flatulence](symptom)
# - My daughter is suffering from [painful gums](symptom), [skin trauma](symptom), [low blood pressure](symptom), [low blood sugar](symptom)
# - My child is suffering from [nipple discharge](symptom), [nasal congestion](symptom), [hand redness](symptom), [calf pain](symptom)
# - I'm suffering from [swelling](symptom), [swollen lymph nodes](symptom), [mouth pain](symptom), [confusion and headache](symptom)
# - I don't feel well, I have [double vision](symptom), [obesity](symptom), [agitated](symptom), [nipple discharge](symptom)
# - My wife is suffering from [vaginal bleeding after menopause](symptom), [hives](symptom), [painful rash](symptom), [groin pain](symptom)
# - I have really bad [congestion in chest or lungs](symptom), [bleeding gums](symptom), [confusion](symptom), [leg ache or pain](symptom)
# - My daughter is suffering from [chest pain](symptom), [vaginal bleeding](symptom), [learning difficulties](symptom), [head injury](symptom)
# - My symptoms are [frequent urination](symptom), [shoulder ache or pain](symptom), [neck swelling](symptom), [muscle spasm](symptom)
# - I have [chest pain](symptom), [ankle pain](symptom), [vomiting](symptom), [agitated](symptom)
# - I don't feel well, I have [hand redness](symptom), [constipation](symptom), [night sweats](symptom), [heart murmur](symptom)
# - My wife is suffering from [penis inflammation or swelling](symptom), [pain in the ear](symptom), [pregnancy problem](symptom), [upper leg pain](symptom)
# - My child is suffering from [leg redness](symptom), [vaginal bleeding during pregnancy](symptom), [puncture wound](symptom), [dizziness](symptom)
# - I'm suffering from [muscle spasm](symptom), [hand redness](symptom), [skin trauma](symptom), [heart pulsations and palpitations](symptom)
# - My symptoms are [shoulder ache or pain](symptom), [painful rash](symptom), [double vision](symptom), [heart pulsations and palpitations](symptom)
# - My symptoms are [arm swelling](symptom), [skin sores](symptom), [night sweats](symptom), [maroon stools](symptom)
# - My husband is suffering from [face numbness](symptom), [swelling of both legs](symptom), [sleep disorders](symptom), [vomiting](symptom)
# - I'm suffering from [psychiatric problem](symptom), [heart murmur](symptom), [hand, finger ache or pain](symptom), [fever in the returning traveler](symptom)
# - My child is suffering from [poisoning](symptom), [toe pain](symptom), [hand, finger ache or pain](symptom), [hemoptysis](symptom)
# - I don't feel well, I have [eye pain](symptom), [calf pain](symptom), [skin pain](symptom), [sneezing](symptom)
# - I have really bad [arm ache or pain](symptom), [cyanosis](symptom), [vomiting coffee ground material](symptom), [nausea](symptom)
# - For the last few days I have had [swollen gums](symptom), [cyanosis](symptom), [painful gums](symptom), [rectal swelling](symptom)
# - My husband is suffering from [foot cut](symptom), [insect sting](symptom), [mouth swelling](symptom), [headache](symptom)
# - I have really bad [dementia](symptom), [blurry vision](symptom), [arm numbness](symptom), [penis pain](symptom)
# - I have really bad [arm numbness](symptom), [facial pain](symptom), [pain in the ear](symptom), [puncture wound](symptom)
# - My symptoms are [amenorrhea](symptom), [painful rash](symptom), [dementia](symptom), [sinus pain and pressure](symptom)
# - I'm suffering from [ear swelling](symptom), [trauma](symptom), [lump or mass of breast](symptom), [flank pain](symptom)
# - My husband is suffering from [tongue swelling](symptom), [laceration](symptom), [unusual color or odor of urine](symptom), [vaginal bleeding](symptom)
# - My child is suffering from [choking](symptom), [increased facial hair](symptom), [blood in urine](symptom), [calf pain](symptom)
# - My husband is suffering from [nail injury](symptom), [vaginal discharge](symptom), [speech problem](symptom), [sweating](symptom)
# - I have [drooping eyelid](symptom), [nausea](symptom), [neck ache or pain](symptom), [memory loss](symptom)
# - My wife is suffering from [upper abdominal pain](symptom), [steatorrhea](symptom), [sleep disorders](symptom), [ear swelling](symptom)
# - For the last few days I have had [calf pain](symptom), [muscle spasm](symptom), [low blood pressure](symptom), [dark stools](symptom)
# - My symptoms are [double vision](symptom), [head injury](symptom), [delusions or hallucinations](symptom), [overdose](symptom)
# - I have [vertigo](symptom), [wrist swelling](symptom), [joint pain](symptom), [arm ache or pain](symptom)
# - I have really bad [amenorrhea](symptom), [confusion and headache](symptom), [drooping eyelid](symptom), [heart pulsations and palpitations](symptom)
# - My wife is suffering from [increased thirst](symptom), [laceration](symptom), [bleeding tendency](symptom), [hip pain](symptom)
# - I don't feel well, I have [high blood sugar](symptom), [bleeding gums](symptom), [ingestion](symptom), [impotence](symptom)
# - My symptoms are [fever in the returning traveler](symptom), [suicidal tendencies](symptom), [ear swelling](symptom), [low blood sugar](symptom)
# - My daughter is suffering from [leg redness](symptom), [cough](symptom), [calf swelling](symptom), [armpit pain](symptom)
# - I have really bad [face numbness](symptom), [retaining fluid](symptom), [fever in the returning traveler](symptom), [spider bite](symptom)
# - My daughter is suffering from [behavioral problem](symptom), [fainting](symptom), [mouth ulcers](symptom), [painful urination](symptom)
# - I'm suffering from [headache](symptom), [facial droop](symptom), [joint pain](symptom), [groin pain](symptom)
# - My symptoms are [discharge from ear](symptom), [tremors](symptom), [flatulence](symptom), [retaining fluid](symptom)
# - I have really bad [constipation](symptom), [urinary retention](symptom), [arm swelling](symptom), [fever in the returning traveler](symptom)
# - My daughter is suffering from [leg redness](symptom), [skin trauma](symptom), [wheezing](symptom), [hemoptysis](symptom)
# - My child is suffering from [skin pain](symptom), [visual flashing lights](symptom), [fever](symptom), [low blood pressure](symptom)
# - My son is suffering from [nail injury](symptom), [dizziness](symptom), [blister](symptom), [trauma](symptom)
# - My daughter is suffering from [hand, finger ache or pain](symptom), [groin pain](symptom), [arm stiffness or tightness](symptom), [alcohol abuse](symptom)
# - My husband is suffering from [lump or mass of breast](symptom), [muscle spasm](symptom), [armpit pain](symptom), [low heart rate](symptom)
# - My husband is suffering from [wrist pain](symptom), [neck ache or pain](symptom), [low blood sugar](symptom), [low blood pressure](symptom)
# - For the last few days I have had [eye floaters](symptom), [hives](symptom), [dark stools](symptom), [arm swelling](symptom)
# - My symptoms are [cough](symptom), [stings](symptom), [dizziness](symptom), [pain in the ear](symptom)
# - For the last few days I have had [numbness](symptom), [fever in the returning traveler](symptom), [vertigo](symptom), [shoulder stiffness or tightness](symptom)
# - I have really bad [increased urination](symptom), [mouth pain](symptom), [blister](symptom), [heel pain](symptom)
# - My symptoms are [vomiting coffee ground material](symptom), [skin trauma](symptom), [speech problem](symptom), [hand numbness](symptom)
# - I have [sore throat](symptom), [stings](symptom), [increased urination](symptom), [itchy rash](symptom)
# - My son is suffering from [nasal injury](symptom), [blurry vision](symptom), [arm stiffness or tightness](symptom), [drooling](symptom)
# - My child is suffering from [heart murmur](symptom), [vomiting](symptom), [facial pain](symptom), [unusual color or odor of urine](symptom)
# - For the last few days I have had [dry skin](symptom), [tremors](symptom), [arm stiffness or tightness](symptom), [vaginal discharge](symptom)
# - My daughter is suffering from [hot skin](symptom), [pain or soreness of breast](symptom), [swelling](symptom), [skin trauma](symptom)
# - My child is suffering from [painful gums](symptom), [penis inflammation or swelling](symptom), [low blood sugar](symptom), [ankle pain](symptom)
# - My child is suffering from [toe pain](symptom), [flatulence](symptom), [hand itching](symptom), [skin sores](symptom)
# - I'm suffering from [learning difficulties](symptom), [shoulder stiffness or tightness](symptom), [leg cut](symptom), [agitated](symptom)
# - My daughter is suffering from [leg numbness](symptom), [scrotal swelling](symptom), [sore throat](symptom), [darkening of the skin](symptom)
# - I'm suffering from [rash](symptom), [discharge from ear](symptom), [foot cut](symptom), [heat illness](symptom)
# - My child is suffering from [chest pain](symptom), [dementia](symptom), [fainting](symptom), [chest burning](symptom)
# - My wife is suffering from [infertility](symptom), [drooping eyelid](symptom), [maroon stools](symptom), [facial droop](symptom)
# - My wife is suffering from [general weakness](symptom), [dementia](symptom), [snake bite](symptom), [suicidal tendencies](symptom)
# - I don't feel well, I have [vaginal discharge](symptom), [back ache or pain](symptom), [hand, finger ache or pain](symptom), [memory loss](symptom)
# - I'm suffering from [learning difficulties](symptom), [skin itching](symptom), [kidney pain](symptom), [pelvic pain](symptom)
# - I have [overdose](symptom), [leg redness](symptom), [shoulder ache or pain](symptom), [headache and weakness](symptom)
# - I have [steatorrhea](symptom), [ear swelling](symptom), [leg numbness](symptom), [kidney pain](symptom)
# - I have [cranky, crying, fussy, irritable child](symptom), [foot swelling](symptom), [shin pain](symptom), [melena](symptom)
# - My daughter is suffering from [foot numbness](symptom), [headache](symptom), [stings](symptom), [cyanosis](symptom)
# - I'm suffering from [painful urination](symptom), [headache](symptom), [ingestion](symptom), [dizziness](symptom)
# - I have [blurry vision](symptom), [hair loss](symptom), [arm redness](symptom), [nasal bleeding](symptom)
# - My husband is suffering from [skin swelling](symptom), [foot pain](symptom), [painful gums](symptom), [calf swelling](symptom)
# - My symptoms are [swollen lymph nodes](symptom), [nasal injury](symptom), [discharge from ear](symptom), [ear pressure](symptom)
# - My wife is suffering from [blister](symptom), [jaundice](symptom), [joint stiffness](symptom), [throat pain](symptom)
# - My son is suffering from [arm swelling](symptom), [chest pressure](symptom), [wheezing](symptom), [neck swelling](symptom)
# - I have [visual flashing lights](symptom), [incontinence](symptom), [rectal swelling](symptom), [ear swelling](symptom)
# - My symptoms are [jaw pain](symptom), [vomiting coffee ground material](symptom), [skin infection](symptom), [leg cut](symptom)
# - My child is suffering from [sweating](symptom), [groin pain](symptom), [hives](symptom), [darkening of the skin](symptom)
# - My wife is suffering from [foot cut](symptom), [wrist swelling](symptom), [nasal bleeding](symptom), [impotence](symptom)
# - My wife is suffering from [nipple discharge](symptom), [increased urination](symptom), [nail injury](symptom), [spider bite](symptom)
# - My husband is suffering from [arm cut](symptom), [steatorrhea](symptom), [swollen lymph nodes](symptom), [leg itching](symptom)
# - My husband is suffering from [dizziness](symptom), [arm itching](symptom), [hand, finger ache or pain](symptom), [kidney pain](symptom)
# - I have [chest burning](symptom), [arm ache or pain](symptom), [sneezing](symptom), [agitated](symptom)
# - I don't feel well, I have [darkening of the skin](symptom), [upper abdominal pain](symptom), [muscle pain](symptom), [skin pain](symptom)
# - My wife is suffering from [lower abdominal pain](symptom), [foot swelling](symptom), [low blood sugar](symptom), [eye redness](symptom)
# - My husband is suffering from [eye floaters](symptom), [shin pain](symptom), [bleeding gums](symptom), [lip swelling](symptom)
# - I have really bad [increased urination](symptom), [vertigo](symptom), [nasal bleeding](symptom), [behavioral problem](symptom)
# - I don't feel well, I have [low blood sugar](symptom), [eye pain](symptom), [swollen gums](symptom), [liver failure](symptom)
# - I have [heel pain](symptom), [hand redness](symptom), [dark stools](symptom), [mouth swelling](symptom)
# - I have really bad [hand itching](symptom), [headache and weakness](symptom), [vaginal discharge](symptom), [joint pain](symptom)
