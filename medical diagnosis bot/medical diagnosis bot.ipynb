# %% [markdown]
# ### Part1 :
# ### Prepare input data for diagnosis portion

# %%
import pandas as pd
import spacy
import random
import re

# %%
nlp = spacy.load('en_core_web_md')

# %%
def get_sentence_vectors(text, nlp):
    
    # get tokens for each word in a sentence
    embedding = nlp(text).vector.tolist()
    
    return embedding

# %% [markdown]
# Import and merge data

# %%
illness_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/dia_t.csv')
symptom_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/sym_t.csv')
links_df = pd.read_csv('/home/ihsan/Documents/GitHub/Rasa/Rasa-Chatbot/medical diagnosis bot/diaganosis symtom/diffsydiw.csv')

# %%
illness_df.head()
# Out:
#    did                                           diagnose
# 0    1  Abdominal aortic aneurysm
# (enlarged major bloo...
# 1    2                                 Abdominal swelling
# 2    3                                   Abdominal trauma
# 3    4                               Abrasions
#  (scrapes)
# 4    5  ACE inhibitor induced cough
# blood pressure med...

# %%
symptom_df.head()
# Out:
#    syd                      symptom
# 0    1         Upper abdominal pain
# 1    2         Lower abdominal pain
# 2    3  Abscess (Collection of pus)
# 3    4                Alcohol abuse
# 4    5        Anxiety (Nervousness)

# %%
source_data = (links_df
               .merge(illness_df, on="did")
               .merge(symptom_df, on="syd"))
source_data
# Out:
#         syd     did  wei                                           diagnose  \
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
# Remove missing data and select columns we needed

source_data = source_data.loc[~(source_data['symptom'].isna()) & ~(source_data['diagnose'].isna()),['did', 'syd', 'diagnose', 'symptom']]

source_data.columns = ['illness_id', 'symptom_id', 'illness', 'symptom']

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis
# inflammation of the gallbladder
# 1                Choledocholithiasis
# stone in bile duct
# 2                             Cholelithiasis
# gallstones
# 3                                          Constipation
# 4                           Gastric ulcer
# stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564                                 Hair loss
# alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %%
# tidy up some new messy characters
source_data['illness'] = source_data['illness'].str.replace('\x0b', ' ')
source_data['symptom'] = source_data['symptom'].str.replace('\x0b', ' ')

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis inflammation of the gallbladder
# 1                Choledocholithiasis stone in bile duct
# 2                             Cholelithiasis gallstones
# 3                                          Constipation
# 4                           Gastric ulcer stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma skin cancer on ...
# 5564                                 Hair loss alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %% [markdown]
# Use our function to convert each symptom to a vector representation we can then save our symptom data down to the data folder

# %%
symptom_df = symptom_df.loc[~symptom_df['symptom'].isna()]

symptom_df['embedding'] = symptom_df.apply(
    lambda row: get_sentence_vectors(row['symptom'], nlp), axis=1)
symptom_df.columns = ['symptom_id', 'symptom', 'symptom_vector']

# %%
symptom_df
# Out:
#      symptom_id                          symptom  \
# 0             1             Upper abdominal pain
# 1             2             Lower abdominal pain
# 2             3      Abscess (Collection of pus)
# 3             4                    Alcohol abuse
# 4             5            Anxiety (Nervousness)
# ..          ...                              ...
# 267         295                 Nipple discharge
# 268         301  Shoulder stiffness or tightness
# 269         303       Arm stiffness or tightness
# 270         304              High blood pressure
# 271         306                 High blood sugar
#
#                                         symptom_vector
# 0    [-0.3931533396244049, -1.122189998626709, -2.3...
# 1    [0.11224666982889175, -1.3984565734863281, -2....
# 2    [-4.394866943359375, -5.325353145599365, 3.294...
# 3    [-1.0100150108337402, -3.2876999378204346, -1....
# 4    [-2.1256749629974365, -4.137800216674805, 4.55...
# ..                                                 ...
# 267  [-1.7614949941635132, 0.5206300020217896, -1.9...
# 268  [-1.2457798719406128, 2.181957483291626, -6.26...
# 269  [-1.7361524105072021, 1.2958674430847168, -4.8...
# 270  [-0.959559977054596, 0.45383667945861816, -2.6...
# 271  [-0.032566625624895096, -1.4907633066177368, -...
#
# [246 rows x 3 columns]

# %%
# remove messy charecters

symptom_df['symptom'] = symptom_df['symptom'].str.replace('\x0b', ' ')

# %%
source_data.to_pickle('data/source_data.pkl')
symptom_df.to_pickle('data/symptoms.pkl')

# %% [markdown]
# ### Create a vector of symtpoms for each illness described in the data

# %% [markdown]
# Here we will loop through each illness described in the dataset
# and flag (with a 1 or 0) each of the symptoms of that illness.
# We will do then compare a list of flagged symptoms described by
# the user to this using a cosine similarity function to diagnose
# a potential illness.

# %%
# list of illness 
illnesses = list(source_data['illness'].drop_duplicates())

# list we will use store our illness vectors 
symptom_vectors = []

for illness in illnesses:
    
    illnesses_symptoms = list(source_data.loc[source_data['illness'] == illness, 'symptom'].drop_duplicates())
    
    symptom_df['related_to_illness'] = 0
    symptom_df.loc[symptom_df['symptom'].isin(illnesses_symptoms), "related_to_illness"] = 1
    
    symptom_vectors.append(list(symptom_df["related_to_illness"]))
    
diagnosis_data = pd.DataFrame({"illness":illnesses,
                                "illness_vector":symptom_vectors})

# %%
diagnosis_data.to_pickle("data/diagnosis_data.pkl")

# %% [markdown]
# ### Part 2:
# ### Generate training samples with flagged entities

# %% [markdown]
# In this part we will attempt to generate some training examples for the NLU model to understand how our users will describe symtoms to the chat bot. To do this we simply loop through our symptoms, sometimes combining them before appending them to different beginnings/endings.
#
# We also make sure to tag any symptom describtions as a symptom entity, which will be understood by Rasa's NLU model. You can see this is accomplished by inserting '(symptom)' beside any mention of symptoms.
#
# The output of this is inserted into nlu.md within the main project.

# %%
number_of_symtoms = [1, 2, 3, 4]
start_of_description = [
    "I have",
    "I'm suffering from",
    "I have really bad",
    "My symptoms are",
    "For the last few days I have had",
    "My husband is suffering from" ,
    "My wife is suffering from",
    "My son is suffering from",
    "My daughter is suffering from",
    "My child is suffering from",
    "I don't feel well, I have"
]

# Get some examples of users describing different number of symtoms 

for symptoms_count in number_of_symtoms:
    
    # make 100 example of each number of symtoms 
    for ex in range(1, 101):
        
        description_beginning = random.choice(start_of_description)
        
        # collect some random symtoms 
        symptom_1 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_2 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_3 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_4 = symptom_df['symptom'].sample(1).iloc[0].lower()
        
        symptoms = [symptom_1, symptom_2, symptom_3, symptom_4]
        symptom_entity = []
        
        # Remove paranthases from symptoms and add nessecary entity tags to symtoms 
        for symptom in symptoms:
            symptom = re.sub(r"\([^)]+\)", "", symptom).strip()
            symptom = f"[{symptom}](symptom)"
            symptom_entity.append(symptom)
            
        symptom_1 = symptom_entity[0]
        symptom_2 = symptom_entity[1]
        symptom_3 = symptom_entity[2]
        symptom_4 = symptom_entity[3]
        
        # Create the training sample strig 
        
        if symptoms_count == 1:
            
            symptom_string = f"- {description_beginning} {symptom_1}"
            
        if symptoms_count == 2:
            
            symptom_string = f"- {description_beginning} {symptom_1} and {symptom_2}"
            
        if symptoms_count == 3:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, and {symptom_3}"
            
        if symptoms_count == 4:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, {symptom_3}, {symptom_4}"
        
        print(symptom_string)
# Out:
# - My wife is suffering from [mouth ulcers](symptom)
# - I'm suffering from [wrist pain](symptom)
# - My son is suffering from [tongue swelling](symptom)
# - My husband is suffering from [head injury](symptom)
# - I don't feel well, I have [depressed](symptom)
# - For the last few days I have had [skin bumps](symptom)
# - My husband is suffering from [psychiatric problem](symptom)
# - My wife is suffering from [vaginal itching](symptom)
# - I have [joint stiffness](symptom)
# - My son is suffering from [double vision](symptom)
# - My son is suffering from [vaginal itching](symptom)
# - I'm suffering from [numbness](symptom)
# - I don't feel well, I have [darkening of the skin](symptom)
# - I have really bad [tremors](symptom)
# - I'm suffering from [chills](symptom)
# - My wife is suffering from [painful urination](symptom)
# - My child is suffering from [shoulder stiffness or tightness](symptom)
# - My child is suffering from [lower abdominal pain](symptom)
# - I have [fever](symptom)
# - My symptoms are [failure to thrive](symptom)
# - My child is suffering from [discharge from ear](symptom)
# - I don't feel well, I have [arm ache or pain](symptom)
# - My son is suffering from [vomiting](symptom)
# - I have [low blood sugar](symptom)
# - My husband is suffering from [hip pain](symptom)
# - For the last few days I have had [heel pain](symptom)
# - I don't feel well, I have [calf swelling](symptom)
# - My child is suffering from [spider bite](symptom)
# - I have really bad [blood in vomit](symptom)
# - I have [frequent urination](symptom)
# - I have really bad [arm swelling](symptom)
# - My symptoms are [double vision](symptom)
# - I'm suffering from [calf swelling](symptom)
# - I don't feel well, I have [unsteady gait](symptom)
# - I have [snake bite](symptom)
# - My symptoms are [high blood pressure](symptom)
# - My child is suffering from [pulling at ears](symptom)
# - My husband is suffering from [facial droop](symptom)
# - I don't feel well, I have [ringing in ears](symptom)
# - I have really bad [pulling at ears](symptom)
# - I don't feel well, I have [psychiatric problem](symptom)
# - My child is suffering from [foot redness](symptom)
# - My child is suffering from [itchy eyes](symptom)
# - I don't feel well, I have [mouth pain](symptom)
# - My son is suffering from [tongue swelling](symptom)
# - I'm suffering from [nipple discharge](symptom)
# - My daughter is suffering from [traveler's diarrhea](symptom)
# - I'm suffering from [ear pressure](symptom)
# - My child is suffering from [overdose](symptom)
# - My daughter is suffering from [traveler's diarrhea](symptom)
# - My wife is suffering from [low heart rate](symptom)
# - My husband is suffering from [abscess](symptom)
# - I have really bad [blurry vision](symptom)
# - My husband is suffering from [vaginal bleeding during pregnancy](symptom)
# - My son is suffering from [hoarse voice](symptom)
# - My daughter is suffering from [blood in urine](symptom)
# - I have really bad [foot pain](symptom)
# - My daughter is suffering from [ear swelling](symptom)
# - For the last few days I have had [weight loss, unexplained](symptom)
# - My child is suffering from [arm ache or pain](symptom)
# - I'm suffering from [joint pain](symptom)
# - My daughter is suffering from [skin growths](symptom)
# - I'm suffering from [swollen gums](symptom)
# - I don't feel well, I have [groin pain](symptom)
# - I don't feel well, I have [arm cut](symptom)
# - My daughter is suffering from [fever in the returning traveler](symptom)
# - My daughter is suffering from [blood in vomit](symptom)
# - I'm suffering from [hand itching](symptom)
# - I'm suffering from [vaginal bleeding](symptom)
# - I have really bad [drooping eyelid](symptom)
# - I have really bad [choking](symptom)
# - I'm suffering from [anxiety](symptom)
# - My wife is suffering from [upper leg pain](symptom)
# - My son is suffering from [constipation](symptom)
# - I have really bad [impotence](symptom)
# - I'm suffering from [hot flashes](symptom)
# - My husband is suffering from [weakness](symptom)
# - My daughter is suffering from [pregnancy problem](symptom)
# - I have [vaginal discharge](symptom)
# - My symptoms are [laceration](symptom)
# - I have [high blood pressure](symptom)
# - I don't feel well, I have [foot numbness](symptom)
# - My symptoms are [darkening of the skin](symptom)
# - My son is suffering from [skin sores](symptom)
# - My wife is suffering from [liver failure](symptom)
# - For the last few days I have had [change in behavior](symptom)
# - My wife is suffering from [hypothermia](symptom)
# - I have [vaginal pain](symptom)
# - I'm suffering from [chest burning](symptom)
# - My child is suffering from [dry skin](symptom)
# - My son is suffering from [arm stiffness or tightness](symptom)
# - My child is suffering from [cyanosis](symptom)
# - My symptoms are [hand numbness](symptom)
# - My son is suffering from [heart pulsations and palpitations](symptom)
# - My daughter is suffering from [skin infection](symptom)
# - I'm suffering from [rash](symptom)
# - My son is suffering from [heart pulsations and palpitations](symptom)
# - I'm suffering from [chills](symptom)
# - My son is suffering from [cyanosis](symptom)
# - My child is suffering from [arm swelling](symptom)
# - I have really bad [lethargy](symptom) and [arm cut](symptom)
# - My child is suffering from [chest burning](symptom) and [vomiting coffee ground material](symptom)
# - For the last few days I have had [fainting](symptom) and [chest burning](symptom)
# - I have really bad [heat illness](symptom) and [laceration](symptom)
# - I have [low heart rate](symptom) and [foot swelling](symptom)
# - My wife is suffering from [skin swelling](symptom) and [facial droop](symptom)
# - My daughter is suffering from [unusual color or odor of urine](symptom) and [nausea](symptom)
# - I don't feel well, I have [kidney pain](symptom) and [hot flashes](symptom)
# - I have [upper leg pain](symptom) and [bloody diarrhea](symptom)
# - My wife is suffering from [blurry vision](symptom) and [blister](symptom)
# - My symptoms are [hemoptysis](symptom) and [ear pressure](symptom)
# - My son is suffering from [shoulder ache or pain](symptom) and [painful gums](symptom)
# - My daughter is suffering from [vaginal pain](symptom) and [choking](symptom)
# - My husband is suffering from [incontinence](symptom) and [memory loss](symptom)
# - My wife is suffering from [trauma](symptom) and [scrotal pain](symptom)
# - I have really bad [amenorrhea](symptom) and [skin swelling](symptom)
# - For the last few days I have had [chest pain](symptom) and [memory loss](symptom)
# - I don't feel well, I have [melena](symptom) and [discharge from ear](symptom)
# - My son is suffering from [snake bite](symptom) and [stomach and abdominal pain](symptom)
# - For the last few days I have had [shin pain](symptom) and [joint pain](symptom)
# - My husband is suffering from [leg cut](symptom) and [weakness](symptom)
# - For the last few days I have had [leg redness](symptom) and [laceration](symptom)
# - I have [headache after trauma](symptom) and [skin sores](symptom)
# - My husband is suffering from [psychiatric problem](symptom) and [foot redness](symptom)
# - I have [congestion in chest or lungs](symptom) and [darkening of the skin](symptom)
# - My husband is suffering from [swelling](symptom) and [high blood sugar](symptom)
# - My husband is suffering from [stomach and abdominal pain](symptom) and [impotence](symptom)
# - My symptoms are [mouth swelling](symptom) and [dark stools](symptom)
# - I have [rash](symptom) and [back ache or pain](symptom)
# - My wife is suffering from [facial droop](symptom) and [high blood sugar](symptom)
# - My wife is suffering from [dark stools](symptom) and [sweating](symptom)
# - My wife is suffering from [neck stiffness or tightness](symptom) and [blood in urine](symptom)
# - My daughter is suffering from [congestion in chest or lungs](symptom) and [foot numbness](symptom)
# - My daughter is suffering from [dry skin](symptom) and [chills](symptom)
# - My child is suffering from [nausea](symptom) and [leg ache or pain](symptom)
# - I don't feel well, I have [high blood sugar](symptom) and [arm swelling](symptom)
# - For the last few days I have had [sleep disorders](symptom) and [vaginal bleeding](symptom)
# - For the last few days I have had [kidney pain](symptom) and [change in behavior](symptom)
# - My husband is suffering from [nausea](symptom) and [nipple discharge](symptom)
# - I have really bad [blood in urine](symptom) and [excessive appetite](symptom)
# - My child is suffering from [eye floaters](symptom) and [flank pain](symptom)
# - My husband is suffering from [pain or soreness of breast](symptom) and [neck ache or pain](symptom)
# - My child is suffering from [vaginal discharge](symptom) and [fainting](symptom)
# - My husband is suffering from [jaw pain](symptom) and [ear pressure](symptom)
# - I have [nasal congestion](symptom) and [low back ache or pain](symptom)
# - I have really bad [chills](symptom) and [increased urination](symptom)
# - I'm suffering from [hand itching](symptom) and [confusion and headache](symptom)
# - I'm suffering from [pulling at ears](symptom) and [low blood sugar](symptom)
# - I have [liver failure](symptom) and [change in behavior](symptom)
# - I'm suffering from [unsteady gait](symptom) and [congestion in chest or lungs](symptom)
# - For the last few days I have had [leg ache or pain](symptom) and [memory loss](symptom)
# - My symptoms are [ankle pain](symptom) and [dementia](symptom)
# - I'm suffering from [blood in urine](symptom) and [darkening of the skin](symptom)
# - My son is suffering from [snake bite](symptom) and [swelling of both legs](symptom)
# - My child is suffering from [cranky, crying, fussy, irritable child](symptom) and [scrotal swelling](symptom)
# - My daughter is suffering from [delusions or hallucinations](symptom) and [nasal injury](symptom)
# - My child is suffering from [low blood pressure](symptom) and [groin pain](symptom)
# - My daughter is suffering from [upper leg pain](symptom) and [low blood sugar](symptom)
# - I have [jaundice](symptom) and [obesity](symptom)
# - My husband is suffering from [snoring](symptom) and [impotence](symptom)
# - My wife is suffering from [elbow swelling](symptom) and [shoulder stiffness or tightness](symptom)
# - My husband is suffering from [mouth swelling](symptom) and [bleeding gums](symptom)
# - My symptoms are [arm itching](symptom) and [eye pain](symptom)
# - I don't feel well, I have [back ache or pain](symptom) and [mouth pain](symptom)
# - My husband is suffering from [hand numbness](symptom) and [nausea](symptom)
# - I'm suffering from [pain in the ear](symptom) and [upper abdominal pain](symptom)
# - My husband is suffering from [fainting](symptom) and [unsteady gait](symptom)
# - For the last few days I have had [hot flashes](symptom) and [cyanosis](symptom)
# - I have [knee pain](symptom) and [speech problem](symptom)
# - My symptoms are [night sweats](symptom) and [swollen lymph nodes](symptom)
# - My daughter is suffering from [seizure](symptom) and [difficulty breathing](symptom)
# - My daughter is suffering from [blood in vomit](symptom) and [overdose](symptom)
# - My wife is suffering from [change in behavior](symptom) and [muscle spasm](symptom)
# - I have really bad [foot numbness](symptom) and [pain or soreness of breast](symptom)
# - My symptoms are [shoulder ache or pain](symptom) and [overdose](symptom)
# - My wife is suffering from [scrotal swelling](symptom) and [confusion](symptom)
# - My symptoms are [obesity](symptom) and [chest burning](symptom)
# - My child is suffering from [swallowing problem](symptom) and [nasal bleeding](symptom)
# - My symptoms are [kidney pain](symptom) and [skin pain](symptom)
# - I have really bad [rectal pain](symptom) and [hot flashes](symptom)
# - My husband is suffering from [scrotal pain](symptom) and [high blood sugar](symptom)
# - My symptoms are [confusion and headache](symptom) and [substance abuse](symptom)
# - I have [sleep disorders](symptom) and [penile discharge](symptom)
# - My husband is suffering from [pustule](symptom) and [knee pain](symptom)
# - My daughter is suffering from [hip pain](symptom) and [facial pain](symptom)
# - My symptoms are [abscess](symptom) and [overdose](symptom)
# - My wife is suffering from [retaining fluid](symptom) and [wrist swelling](symptom)
# - My child is suffering from [chills](symptom) and [shin pain](symptom)
# - I'm suffering from [leg redness](symptom) and [incontinence](symptom)
# - I have really bad [limping in a child](symptom) and [chest pressure](symptom)
# - My son is suffering from [penis inflammation or swelling](symptom) and [infertility](symptom)
# - I have [blister](symptom) and [hand, finger ache or pain](symptom)
# - My child is suffering from [dry skin](symptom) and [darkening of the skin](symptom)
# - My son is suffering from [low heart rate](symptom) and [loss of balance](symptom)
# - My symptoms are [eye floaters](symptom) and [high blood sugar](symptom)
# - My son is suffering from [joint pain](symptom) and [incontinence](symptom)
# - My wife is suffering from [calf pain](symptom) and [learning difficulties](symptom)
# - My son is suffering from [anger](symptom) and [swollen lymph nodes](symptom)
# - For the last few days I have had [skin itching](symptom) and [high blood pressure](symptom)
# - I don't feel well, I have [mouth ulcers](symptom) and [foot swelling](symptom)
# - My symptoms are [weakness](symptom), [neck ache or pain](symptom), and [numbness](symptom)
# - My daughter is suffering from [confusion and headache](symptom), [cyanosis](symptom), and [skin pain](symptom)
# - I don't feel well, I have [insomnia](symptom), [traveler's diarrhea](symptom), and [ear pressure](symptom)
# - I don't feel well, I have [psychiatric problem](symptom), [vaginal itching](symptom), and [toe pain](symptom)
# - I have really bad [learning difficulties](symptom), [hypothermia](symptom), and [general weakness](symptom)
# - My symptoms are [fever in the returning traveler](symptom), [learning difficulties](symptom), and [trauma](symptom)
# - My symptoms are [pulling at ears](symptom), [drooping eyelid](symptom), and [cranky, crying, fussy, irritable child](symptom)
# - My daughter is suffering from [learning difficulties](symptom), [skin itching](symptom), and [arm itching](symptom)
# - My wife is suffering from [ear swelling](symptom), [low blood sugar](symptom), and [vomiting coffee ground material](symptom)
# - My son is suffering from [low back ache or pain](symptom), [elbow ache or pain](symptom), and [nasal congestion](symptom)
# - My daughter is suffering from [lump or mass of breast](symptom), [double vision](symptom), and [snake bite](symptom)
# - I have really bad [ear swelling](symptom), [fainting](symptom), and [sneezing](symptom)
# - I'm suffering from [tooth pain](symptom), [choking](symptom), and [rash](symptom)
# - My child is suffering from [scrotal swelling](symptom), [shortness of breath](symptom), and [inconsolable baby](symptom)
# - I have [arm cut](symptom), [tired](symptom), and [sneezing](symptom)
# - For the last few days I have had [headache](symptom), [wheezing](symptom), and [excessive appetite](symptom)
# - My husband is suffering from [rectal pain](symptom), [abscess](symptom), and [darkening of the skin](symptom)
# - My symptoms are [back ache or pain](symptom), [vaginal itching](symptom), and [neck ache or pain](symptom)
# - My wife is suffering from [ringing in ears](symptom), [increased urination](symptom), and [limping in a child](symptom)
# - I have really bad [groin pain](symptom), [weakness](symptom), and [jaw pain](symptom)
# - I have [low blood sugar](symptom), [hair loss](symptom), and [hot skin](symptom)
# - My symptoms are [hand, finger ache or pain](symptom), [facial pain](symptom), and [learning difficulties](symptom)
# - I'm suffering from [hot skin](symptom), [chest burning](symptom), and [itchy rash](symptom)
# - My son is suffering from [puncture wound](symptom), [hemoptysis](symptom), and [low heart rate](symptom)
# - I'm suffering from [arm redness](symptom), [vertigo](symptom), and [hand itching](symptom)
# - I'm suffering from [rectal pain](symptom), [lump or mass of breast](symptom), and [penis pain](symptom)
# - My son is suffering from [foot itching](symptom), [foot redness](symptom), and [headache after trauma](symptom)
# - My child is suffering from [toe pain](symptom), [scrotal swelling](symptom), and [fever](symptom)
# - My wife is suffering from [neck swelling](symptom), [skin swelling](symptom), and [high blood sugar](symptom)
# - My daughter is suffering from [leg numbness](symptom), [ringing in ears](symptom), and [arm numbness](symptom)
# - My son is suffering from [painful rash](symptom), [hair loss](symptom), and [learning difficulties](symptom)
# - My daughter is suffering from [ankle pain](symptom), [confusion](symptom), and [stings](symptom)
# - I don't feel well, I have [tremors](symptom), [leg numbness](symptom), and [upper leg pain](symptom)
# - I have [arm itching](symptom), [groin pain](symptom), and [jaw pain](symptom)
# - My husband is suffering from [delusions or hallucinations](symptom), [swelling of both legs](symptom), and [obesity](symptom)
# - For the last few days I have had [fever of unknown origin](symptom), [inconsolable baby](symptom), and [head injury](symptom)
# - My child is suffering from [head injury](symptom), [shoulder stiffness or tightness](symptom), and [behavioral problem](symptom)
# - I'm suffering from [vaginal bleeding during pregnancy](symptom), [melena](symptom), and [leg itching](symptom)
# - I'm suffering from [fever](symptom), [amenorrhea](symptom), and [neck stiffness or tightness](symptom)
# - My husband is suffering from [low blood pressure](symptom), [heel pain](symptom), and [depressed](symptom)
# - My wife is suffering from [nail injury](symptom), [retaining fluid](symptom), and [lip swelling](symptom)
# - My husband is suffering from [leg redness](symptom), [hand numbness](symptom), and [flank pain](symptom)
# - For the last few days I have had [hemoptysis](symptom), [heel pain](symptom), and [maroon stools](symptom)
# - I have [nasal bleeding](symptom), [neck stiffness or tightness](symptom), and [maroon stools](symptom)
# - I have really bad [arm stiffness or tightness](symptom), [lethargy](symptom), and [neck ache or pain](symptom)
# - I'm suffering from [hair loss](symptom), [increased thirst](symptom), and [leg numbness](symptom)
# - My symptoms are [fever in the returning traveler](symptom), [hives](symptom), and [discharge from ear](symptom)
# - My symptoms are [unsteady gait](symptom), [armpit pain](symptom), and [low heart rate](symptom)
# - For the last few days I have had [lower abdominal pain](symptom), [dark stools](symptom), and [pulling at ears](symptom)
# - I have really bad [skin bumps](symptom), [hurts to breathe](symptom), and [choking](symptom)
# - I have [dizziness](symptom), [increased facial hair](symptom), and [nail injury](symptom)
# - I have [foot swelling](symptom), [confusion](symptom), and [unsteady gait](symptom)
# - I'm suffering from [chest pain](symptom), [lump or mass of breast](symptom), and [low blood sugar](symptom)
# - For the last few days I have had [puncture wound](symptom), [unsteady gait](symptom), and [darkening of the skin](symptom)
# - My symptoms are [tongue swelling](symptom), [hand, finger ache or pain](symptom), and [toe pain](symptom)
# - My daughter is suffering from [dementia](symptom), [nasal injury](symptom), and [muscle pain](symptom)
# - My symptoms are [vomiting coffee ground material](symptom), [change in behavior](symptom), and [nausea](symptom)
# - My symptoms are [learning difficulties](symptom), [upper abdominal pain](symptom), and [insect sting](symptom)
# - I don't feel well, I have [traveler's diarrhea](symptom), [blister](symptom), and [calf pain](symptom)
# - My daughter is suffering from [spider bite](symptom), [vomiting](symptom), and [learning difficulties](symptom)
# - I have really bad [incontinence](symptom), [groin pain](symptom), and [heel pain](symptom)
# - I don't feel well, I have [facial droop](symptom), [heat illness](symptom), and [skin sores](symptom)
# - I have [tired](symptom), [swelling](symptom), and [overdose](symptom)
# - My son is suffering from [wheezing](symptom), [retaining fluid](symptom), and [skin growths](symptom)
# - My child is suffering from [hand itching](symptom), [general weakness](symptom), and [leg ache or pain](symptom)
# - My son is suffering from [hand redness](symptom), [puncture wound](symptom), and [sleep disorders](symptom)
# - I have [elbow swelling](symptom), [swallowing problem](symptom), and [kidney pain](symptom)
# - My symptoms are [shoulder ache or pain](symptom), [melena](symptom), and [substance abuse](symptom)
# - I have really bad [jaundice](symptom), [elbow swelling](symptom), and [eye swelling](symptom)
# - My child is suffering from [shin pain](symptom), [cranky, crying, fussy, irritable child](symptom), and [overdose](symptom)
# - I'm suffering from [confusion and headache](symptom), [liver failure](symptom), and [skin infection](symptom)
# - I don't feel well, I have [foot pain](symptom), [confusion](symptom), and [blurry vision](symptom)
# - I don't feel well, I have [stings](symptom), [hives](symptom), and [fever of unknown origin](symptom)
# - My symptoms are [maroon stools](symptom), [lower abdominal pain](symptom), and [change in behavior](symptom)
# - I have really bad [skin swelling](symptom), [dizziness](symptom), and [fever](symptom)
# - I'm suffering from [mouth ulcers](symptom), [vaginal discharge](symptom), and [weight loss, unexplained](symptom)
# - My son is suffering from [retaining fluid](symptom), [suicidal tendencies](symptom), and [sweating](symptom)
# - I don't feel well, I have [arm swelling](symptom), [mouth swelling](symptom), and [seizure](symptom)
# - I have [nasal congestion](symptom), [hair loss](symptom), and [vaginal itching](symptom)
# - I don't feel well, I have [vaginal bleeding during pregnancy](symptom), [arm cut](symptom), and [foot redness](symptom)
# - I have really bad [calf swelling](symptom), [excessive appetite](symptom), and [muscle spasm](symptom)
# - My son is suffering from [darkening of the skin](symptom), [heart pulsations and palpitations](symptom), and [high blood pressure](symptom)
# - My symptoms are [vaginal bleeding](symptom), [eye floaters](symptom), and [arm redness](symptom)
# - My wife is suffering from [skin trauma](symptom), [vaginal itching](symptom), and [sweating](symptom)
# - For the last few days I have had [mouth swelling](symptom), [pain or soreness of breast](symptom), and [foot pain](symptom)
# - I have [tooth pain](symptom), [skin infection](symptom), and [weight loss, unexplained](symptom)
# - I don't feel well, I have [dizziness](symptom), [throat pain](symptom), and [shoulder stiffness or tightness](symptom)
# - I have really bad [laceration](symptom), [upper abdominal pain](symptom), and [bleeding in brain](symptom)
# - My husband is suffering from [laceration](symptom), [depressed](symptom), and [ear swelling](symptom)
# - I have really bad [obesity](symptom), [upper leg pain](symptom), and [behavioral problem](symptom)
# - I don't feel well, I have [bleeding tendency](symptom), [vaginal bleeding during pregnancy](symptom), and [obesity](symptom)
# - I'm suffering from [facial droop](symptom), [learning difficulties](symptom), and [vomiting](symptom)
# - For the last few days I have had [kidney pain](symptom), [headache and weakness](symptom), and [knee pain](symptom)
# - My child is suffering from [pain or soreness of breast](symptom), [dizziness](symptom), and [penis pain](symptom)
# - I have [bleeding in brain](symptom), [dry skin](symptom), and [blood in vomit](symptom)
# - My child is suffering from [hoarse voice](symptom), [change in behavior](symptom), and [painful urination](symptom)
# - I have [nasal injury](symptom), [confusion](symptom), and [excessive appetite](symptom)
# - I'm suffering from [diarrhea](symptom), [vaginal bleeding during pregnancy](symptom), and [discharge from ear](symptom)
# - My symptoms are [shortness of breath](symptom), [blood in vomit](symptom), and [weight loss, unexplained](symptom)
# - My symptoms are [elbow ache or pain](symptom), [pregnancy problem](symptom), and [impotence](symptom)
# - I have really bad [arm swelling](symptom), [blood in vomit](symptom), [agitated](symptom), [weight loss, unexplained](symptom)
# - My child is suffering from [sweating](symptom), [arm numbness](symptom), [constipation](symptom), [eye redness](symptom)
# - I have really bad [shoulder stiffness or tightness](symptom), [rash](symptom), [low blood sugar](symptom), [leg ache or pain](symptom)
# - I have really bad [stings](symptom), [blood in urine](symptom), [heart murmur](symptom), [infertility](symptom)
# - My husband is suffering from [head injury](symptom), [skin pain](symptom), [toe pain](symptom), [choking](symptom)
# - I don't feel well, I have [sore throat](symptom), [hoarse voice](symptom), [nail injury](symptom), [nipple discharge](symptom)
# - I'm suffering from [maroon stools](symptom), [swallowing problem](symptom), [weakness](symptom), [dry skin](symptom)
# - My symptoms are [congestion in chest or lungs](symptom), [ingestion](symptom), [foot cut](symptom), [psychiatric problem](symptom)
# - I have [frequent urination](symptom), [itchy eyes](symptom), [elbow swelling](symptom), [anger](symptom)
# - My husband is suffering from [penile discharge](symptom), [wrist swelling](symptom), [hand cut](symptom), [foot redness](symptom)
# - I have really bad [blood in vomit](symptom), [agitated](symptom), [vaginal bleeding](symptom), [cough](symptom)
# - For the last few days I have had [skin bumps](symptom), [behavioral problem](symptom), [tremors](symptom), [neck stiffness or tightness](symptom)
# - My wife is suffering from [learning difficulties](symptom), [sinus pain and pressure](symptom), [insomnia](symptom), [muscle spasm](symptom)
# - I don't feel well, I have [foot swelling](symptom), [unusual color or odor of urine](symptom), [mouth ulcers](symptom), [eye floaters](symptom)
# - I have [psychiatric problem](symptom), [hair loss](symptom), [abdominal swelling](symptom), [arm redness](symptom)
# - My symptoms are [dizziness](symptom), [unsteady gait](symptom), [leg cut](symptom), [hand redness](symptom)
# - I don't feel well, I have [painful gums](symptom), [sore throat](symptom), [sleep disorders](symptom), [ankle pain](symptom)
# - For the last few days I have had [foot pain](symptom), [high blood sugar](symptom), [skin growths](symptom), [flank pain](symptom)
# - My son is suffering from [constipation](symptom), [muscle pain](symptom), [bloody diarrhea](symptom), [flank pain](symptom)
# - I have [suicidal tendencies](symptom), [substance abuse](symptom), [skin infection](symptom), [low blood sugar](symptom)
# - My wife is suffering from [arm swelling](symptom), [bleeding tendency](symptom), [knee pain](symptom), [leg redness](symptom)
# - I don't feel well, I have [snake bite](symptom), [insomnia](symptom), [pregnancy problem](symptom), [hip pain](symptom)
# - I have [hot skin](symptom), [learning difficulties](symptom), [calf swelling](symptom), [arm ache or pain](symptom)
# - I'm suffering from [heart murmur](symptom), [change in behavior](symptom), [chest pressure](symptom), [calf pain](symptom)
# - My wife is suffering from [arm stiffness or tightness](symptom), [wrist swelling](symptom), [leg numbness](symptom), [lip swelling](symptom)
# - My daughter is suffering from [skin infection](symptom), [itchy rash](symptom), [painful gums](symptom), [psychiatric problem](symptom)
# - My child is suffering from [neck ache or pain](symptom), [sneezing](symptom), [rectal pain](symptom), [headache after trauma](symptom)
# - My son is suffering from [discharge from ear](symptom), [congestion in chest or lungs](symptom), [low heart rate](symptom), [inconsolable baby](symptom)
# - I have really bad [painful gums](symptom), [dementia](symptom), [behavioral problem](symptom), [wrist swelling](symptom)
# - My husband is suffering from [insect sting](symptom), [general weakness](symptom), [hoarse voice](symptom), [abdominal swelling](symptom)
# - My wife is suffering from [pelvic pain](symptom), [inconsolable baby](symptom), [blood in urine](symptom), [speech problem](symptom)
# - My daughter is suffering from [wheezing](symptom), [neck swelling](symptom), [pregnancy problem](symptom), [abdominal swelling](symptom)
# - My wife is suffering from [excessive appetite](symptom), [poisoning](symptom), [shoulder stiffness or tightness](symptom), [sneezing](symptom)
# - My child is suffering from [foot redness](symptom), [retaining fluid](symptom), [trauma](symptom), [cough](symptom)
# - I have really bad [retaining fluid](symptom), [stomach and abdominal pain](symptom), [vomiting coffee ground material](symptom), [steatorrhea](symptom)
# - My child is suffering from [dementia](symptom), [foot numbness](symptom), [hand itching](symptom), [puncture wound](symptom)
# - I have [knee pain](symptom), [neck stiffness or tightness](symptom), [foot cut](symptom), [sleep disorders](symptom)
# - My child is suffering from [failure to thrive](symptom), [leg ache or pain](symptom), [incontinence](symptom), [mouth pain](symptom)
# - My wife is suffering from [foot swelling](symptom), [shoulder stiffness or tightness](symptom), [cough](symptom), [depressed](symptom)
# - My symptoms are [vaginal pain](symptom), [upper abdominal pain](symptom), [ingestion](symptom), [speech problem](symptom)
# - For the last few days I have had [heart murmur](symptom), [failure to thrive](symptom), [skin trauma](symptom), [pustule](symptom)
# - My son is suffering from [pain in the ear](symptom), [joint pain](symptom), [failure to thrive](symptom), [nasal injury](symptom)
# - I have really bad [increased urination](symptom), [depressed](symptom), [infertility](symptom), [obesity](symptom)
# - My symptoms are [lower abdominal pain](symptom), [heart murmur](symptom), [limping in a child](symptom), [vaginal pain](symptom)
# - My wife is suffering from [dementia](symptom), [puncture wound](symptom), [visual flashing lights](symptom), [ear swelling](symptom)
# - I don't feel well, I have [learning difficulties](symptom), [painful urination](symptom), [nasal bleeding](symptom), [confusion](symptom)
# - My son is suffering from [headache](symptom), [incontinence](symptom), [memory loss](symptom), [chest burning](symptom)
# - My daughter is suffering from [chills](symptom), [insect sting](symptom), [skin swelling](symptom), [visual problems](symptom)
# - My symptoms are [lip swelling](symptom), [spider bite](symptom), [impotence](symptom), [snoring](symptom)
# - I don't feel well, I have [ankle pain](symptom), [painful urination](symptom), [traveler's diarrhea](symptom), [abdominal swelling](symptom)
# - For the last few days I have had [heart murmur](symptom), [visual flashing lights](symptom), [hand cut](symptom), [heart pulsations and palpitations](symptom)
# - I have really bad [pain in the ear](symptom), [change in behavior](symptom), [congestion in chest or lungs](symptom), [mouth pain](symptom)
# - I have [painful urination](symptom), [dizziness](symptom), [arm numbness](symptom), [pulling at ears](symptom)
# - My husband is suffering from [scrotal pain](symptom), [choking](symptom), [lip swelling](symptom), [pulling at ears](symptom)
# - I'm suffering from [eye floaters](symptom), [urinary retention](symptom), [seizure](symptom), [skin swelling](symptom)
# - My daughter is suffering from [double vision](symptom), [elbow ache or pain](symptom), [flatulence](symptom), [frequent urination](symptom)
# - My daughter is suffering from [arm swelling](symptom), [discharge from ear](symptom), [low back ache or pain](symptom), [blood in urine](symptom)
# - My child is suffering from [vaginal bleeding after menopause](symptom), [eye redness](symptom), [cyanosis](symptom), [incontinence](symptom)
# - My symptoms are [mouth swelling](symptom), [puncture wound](symptom), [flatulence](symptom), [frequent urination](symptom)
# - My husband is suffering from [muscle spasm](symptom), [kidney pain](symptom), [increased facial hair](symptom), [laceration](symptom)
# - My child is suffering from [nasal congestion](symptom), [chest pressure](symptom), [seizure](symptom), [calf swelling](symptom)
# - I don't feel well, I have [neck ache or pain](symptom), [cough](symptom), [joint stiffness](symptom), [eye swelling](symptom)
# - I don't feel well, I have [tongue swelling](symptom), [inconsolable baby](symptom), [choking](symptom), [general weakness](symptom)
# - My wife is suffering from [lower abdominal pain](symptom), [arm stiffness or tightness](symptom), [difficulty breathing](symptom), [hand redness](symptom)
# - My wife is suffering from [skin itching](symptom), [shoulder stiffness or tightness](symptom), [chest pain](symptom), [cough](symptom)
# - My wife is suffering from [hives](symptom), [neck swelling](symptom), [nipple discharge](symptom), [weight loss, unexplained](symptom)
# - I have really bad [wrist pain](symptom), [pustule](symptom), [heat illness](symptom), [urinary retention](symptom)
# - I have really bad [joint stiffness](symptom), [scrotal swelling](symptom), [difficulty breathing](symptom), [amenorrhea](symptom)
# - My wife is suffering from [joint pain](symptom), [skin itching](symptom), [infertility](symptom), [ankle pain](symptom)
# - I'm suffering from [wrist pain](symptom), [increased urination](symptom), [vertigo](symptom), [low blood sugar](symptom)
# - My husband is suffering from [increased facial hair](symptom), [incontinence](symptom), [leg redness](symptom), [leg itching](symptom)
# - I'm suffering from [arm stiffness or tightness](symptom), [urinary retention](symptom), [skin swelling](symptom), [rash](symptom)
# - For the last few days I have had [high blood pressure](symptom), [seizure](symptom), [stings](symptom), [increased thirst](symptom)
# - I don't feel well, I have [mouth ulcers](symptom), [neck ache or pain](symptom), [shortness of breath](symptom), [penile discharge](symptom)
# - My child is suffering from [vaginal bleeding during pregnancy](symptom), [insomnia](symptom), [blood in urine](symptom), [unusual color or odor of urine](symptom)
# - My child is suffering from [bleeding gums](symptom), [memory loss](symptom), [nipple discharge](symptom), [dementia](symptom)
# - My husband is suffering from [wheezing](symptom), [chest pain](symptom), [fever of unknown origin](symptom), [tired](symptom)
# - My wife is suffering from [arm stiffness or tightness](symptom), [neck swelling](symptom), [confusion and headache](symptom), [lip swelling](symptom)
# - I'm suffering from [high blood sugar](symptom), [abdominal swelling](symptom), [excessive appetite](symptom), [skin growths](symptom)
# - My daughter is suffering from [upper leg pain](symptom), [eye swelling](symptom), [increased thirst](symptom), [melena](symptom)
# - For the last few days I have had [vaginal bleeding](symptom), [low heart rate](symptom), [itchy eyes](symptom), [facial pain](symptom)
# - My symptoms are [retaining fluid](symptom), [drooping eyelid](symptom), [hair loss](symptom), [anger](symptom)
# - My symptoms are [hand itching](symptom), [unsteady gait](symptom), [increased urination](symptom), [scrotal pain](symptom)
# - I have [low heart rate](symptom), [rectal pain](symptom), [armpit pain](symptom), [double vision](symptom)
# - My child is suffering from [leg redness](symptom), [chest burning](symptom), [skin infection](symptom), [visual flashing lights](symptom)
# - I have really bad [swelling](symptom), [anxiety](symptom), [neck stiffness or tightness](symptom), [fever in the returning traveler](symptom)
# - My son is suffering from [bleeding tendency](symptom), [hot flashes](symptom), [rectal swelling](symptom), [heart pulsations and palpitations](symptom)
# - My husband is suffering from [melena](symptom), [bloody diarrhea](symptom), [skin swelling](symptom), [failure to thrive](symptom)
# - My daughter is suffering from [bloody diarrhea](symptom), [eye floaters](symptom), [infertility](symptom), [bloody diarrhea](symptom)
# - I don't feel well, I have [overdose](symptom), [cyanosis](symptom), [rectal pain](symptom), [swelling](symptom)
# - My wife is suffering from [hurts to breathe](symptom), [rash](symptom), [bleeding in brain](symptom), [eye redness](symptom)
# - My daughter is suffering from [heel pain](symptom), [high blood pressure](symptom), [foot cut](symptom), [hurts to breathe](symptom)
# - My husband is suffering from [jaw pain](symptom), [hot skin](symptom), [unusual color or odor of urine](symptom), [constipation](symptom)
# - I'm suffering from [ankle pain](symptom), [bleeding tendency](symptom), [darkening of the skin](symptom), [hoarse voice](symptom)
# - My wife is suffering from [darkening of the skin](symptom), [hypothermia](symptom), [learning difficulties](symptom), [neck ache or pain](symptom)
# - My child is suffering from [mouth pain](symptom), [retaining fluid](symptom), [hoarse voice](symptom), [drooling](symptom)
# - My daughter is suffering from [blister](symptom), [insect sting](symptom), [weight loss, unexplained](symptom), [delusions or hallucinations](symptom)
# - My husband is suffering from [bleeding tendency](symptom), [penis pain](symptom), [melena](symptom), [ankle pain](symptom)
# - I have [suicidal tendencies](symptom), [leg itching](symptom), [difficulty breathing](symptom), [joint pain](symptom)
# - For the last few days I have had [blood in urine](symptom), [cyanosis](symptom), [insect sting](symptom), [cranky, crying, fussy, irritable child](symptom)
