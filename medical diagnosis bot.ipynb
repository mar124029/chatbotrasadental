# %% [markdown]
# ### Part1 :
# ### Prepare input data for diagnosis portion

# %%
import pandas as pd
import spacy
import random
import re

# %%
nlp = spacy.load('en_core_web_md')

# %%
def get_sentence_vectors(text, nlp):
    
    # get tokens for each word in a sentence
    embedding = nlp(text).vector.tolist()
    
    return embedding

# %% [markdown]
# Import and merge data

# %%
illness_df = pd.read_csv('diaganosis symtom/dia_t.csv')
symptom_df = pd.read_csv('diaganosis symtom/sym_t.csv')
links_df = pd.read_csv('diaganosis symtom/diffsydiw.csv')

# %%
illness_df.head()
# Out:
#    did                                           diagnose
# 0    1  Abdominal aortic aneurysm
# (enlarged major bloo...
# 1    2                                 Abdominal swelling
# 2    3                                   Abdominal trauma
# 3    4                               Abrasions
#  (scrapes)
# 4    5  ACE inhibitor induced cough
# blood pressure med...

# %%
symptom_df.head()
# Out:
#    syd                      symptom
# 0    1         Upper abdominal pain
# 1    2         Lower abdominal pain
# 2    3  Abscess (Collection of pus)
# 3    4                Alcohol abuse
# 4    5        Anxiety (Nervousness)

# %%
source_data = (links_df
               .merge(illness_df, on="did")
               .merge(symptom_df, on="syd"))
source_data
# Out:
#         syd     did  wei                                           diagnose  \
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
source_data
# Out:
#         syd     did  wei                                           diagnose  \
# 0       1.0   163.0  2.0      Cholecystitis
# inflammation of the gallbladder
# 1       1.0   164.0  2.0             Choledocholithiasis
# stone in bile duct
# 2       1.0   165.0  1.0                          Cholelithiasis
# gallstones
# 3       1.0   187.0  2.0                                       Constipation
# 4       1.0   306.0  2.0                        Gastric ulcer
# stomach ulcer
# ...     ...     ...  ...                                                ...
# 5563  106.0   827.0  0.0  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564  186.0   966.0  2.0                                 Hair loss
# alopecia
# 5565  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5566  186.0  1415.0  0.0                                 Hypoparathyroidism
# 5567  186.0  1245.0  1.0  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5568 rows x 5 columns]

# %%
# Remove missing data and select columns we needed

source_data = source_data.loc[~(source_data['symptom'].isna()) & ~(source_data['diagnose'].isna()),['did', 'syd', 'diagnose', 'symptom']]

source_data.columns = ['illness_id', 'symptom_id', 'illness', 'symptom']

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis
# inflammation of the gallbladder
# 1                Choledocholithiasis
# stone in bile duct
# 2                             Cholelithiasis
# gallstones
# 3                                          Constipation
# 4                           Gastric ulcer
# stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma
# skin cancer on ...
# 5564                                 Hair loss
# alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss
# hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %%
# tidy up some new messy characters
source_data['illness'] = source_data['illness'].str.replace('\x0b', ' ')
source_data['symptom'] = source_data['symptom'].str.replace('\x0b', ' ')

# %%
source_data
# Out:
#       illness_id  symptom_id  \
# 0          163.0         1.0
# 1          164.0         1.0
# 2          165.0         1.0
# 3          187.0         1.0
# 4          306.0         1.0
# ...          ...         ...
# 5563       827.0       106.0
# 5564       966.0       186.0
# 5565      1415.0       186.0
# 5566      1415.0       186.0
# 5567      1245.0       186.0
#
#                                                 illness  \
# 0         Cholecystitis inflammation of the gallbladder
# 1                Choledocholithiasis stone in bile duct
# 2                             Cholelithiasis gallstones
# 3                                          Constipation
# 4                           Gastric ulcer stomach ulcer
# ...                                                 ...
# 5563  Vulvar squamous cell carcinoma skin cancer on ...
# 5564                                 Hair loss alopecia
# 5565                                 Hypoparathyroidism
# 5566                                 Hypoparathyroidism
# 5567  Male pattern hair loss hereditary-patterned ba...
#
#                                symptom
# 0                 Upper abdominal pain
# 1                 Upper abdominal pain
# 2                 Upper abdominal pain
# 3                 Upper abdominal pain
# 4                 Upper abdominal pain
# ...                                ...
# 5563  Vaginal bleeding after menopause
# 5564              Hair loss (Baldness)
# 5565              Hair loss (Baldness)
# 5566              Hair loss (Baldness)
# 5567              Hair loss (Baldness)
#
# [5204 rows x 4 columns]

# %% [markdown]
# Use our function to convert each symptom to a vector representation we can then save our symptom data down to the data folder

# %%
symptom_df = symptom_df.loc[~symptom_df['symptom'].isna()]

symptom_df['embedding'] = symptom_df.apply(lambda row: get_sentence_vectors(row['symptom'], nlp), axis=1)
symptom_df.columns = ['symptom_id', 'symptom', 'symptom_vector']

# %%
symptom_df
# Out:
#      symptom_id                          symptom  \
# 0             1             Upper abdominal pain
# 1             2             Lower abdominal pain
# 2             3      Abscess (Collection of pus)
# 3             4                    Alcohol abuse
# 4             5            Anxiety (Nervousness)
# ..          ...                              ...
# 267         295                 Nipple discharge
# 268         301  Shoulder stiffness or tightness
# 269         303       Arm stiffness or tightness
# 270         304              High blood pressure
# 271         306                 High blood sugar
#
#                                         symptom_vector
# 0    [-0.3931533396244049, -1.122189998626709, -2.3...
# 1    [0.11224666982889175, -1.3984565734863281, -2....
# 2    [-4.394866943359375, -5.325353145599365, 3.294...
# 3    [-1.0100150108337402, -3.2876999378204346, -1....
# 4    [-2.1256749629974365, -4.137800216674805, 4.55...
# ..                                                 ...
# 267  [-1.7614949941635132, 0.5206300020217896, -1.9...
# 268  [-1.2457798719406128, 2.181957483291626, -6.26...
# 269  [-1.7361524105072021, 1.2958674430847168, -4.8...
# 270  [-0.959559977054596, 0.45383667945861816, -2.6...
# 271  [-0.032566625624895096, -1.4907633066177368, -...
#
# [246 rows x 3 columns]

# %%
# remove messy charecters

symptom_df['symptom'] = symptom_df['symptom'].str.replace('\x0b', ' ')

# %%
source_data.to_pickle('input_data/source_data.pkl')
symptom_df.to_pickle('input_data/symptoms.pkl')

# %% [markdown]
# ### Create a vector of symtpoms for each illness described in the data

# %% [markdown]
# Here we will loop through each illness described in the dataset
# and flag (with a 1 or 0) each of the symptoms of that illness.
# We will do then compare a list of flagged symptoms described by
# the user to this using a cosine similarity function to diagnose
# a potential illness.

# %%
print(source_data.columns)
# Out:
# Index(['illness_id', 'symptom_id', 'illness', 'symptom'], dtype='object')

# %%
# list of illness 
illnesses = list(source_data['illness'].drop_duplicates())

# list we will use store our illness vectors 
symptom_vectors = []

for illness in illnesses:
    
    illnesses_symptoms = list(source_data.loc[source_data['illness'] == illness, 'symptom'].drop_duplicates())
    
    symptom_df['related_to_illness'] = 0
    symptom_df.loc[symptom_df['symptom'].isin(illnesses_symptoms), "related_to_illness"] = 1
    
    symptom_vectors.append(list(symptom_df["related_to_illness"]))
    
diagnosis_data = pd.DataFrame({"illness":illnesses,
                                "illness_vector":symptom_vectors})
diagnosis_data.to_pickle('input_data/diagnosis_data.pkl')

# %%
print(source_data.columns)
# Out:
# Index(['illness_id', 'symptom_id', 'illness', 'symptom'], dtype='object')

# %%
print(source_data.columns)
# Out:
# Index(['illness_id', 'symptom_id', 'illness', 'symptom'], dtype='object')

# %%
print(source_data.columns)
# Out:
# Index(['illness_id', 'symptom_id', 'illness', 'symptom'], dtype='object')

# %%
print(source_data.columns)
# Out:
# Index(['illness_id', 'symptom_id', 'illness', 'symptom'], dtype='object')

# %% [markdown]
# ### Part 2:
# ### Generate training samples with flagged entities

# %% [markdown]
# In this part we will attempt to generate some training examples for the NLU model to understand how our users will describe symtoms to the chat bot. To do this we simply loop through our symptoms, sometimes combining them before appending them to different beginnings/endings.
#
# We also make sure to tag any symptom describtions as a symptom entity, which will be understood by Rasa's NLU model. You can see this is accomplished by inserting '(symptom)' beside any mention of symptoms.
#
# The output of this is inserted into nlu.md within the main project.

# %%
number_of_symtoms = [1, 2, 3, 4]
start_of_description = [
    "I have",
    "I'm suffering from",
    "I have really bad",
    "My symptoms are",
    "For the last few days I have had",
    "My husband is suffering from" ,
    "My wife is suffering from",
    "My son is suffering from",
    "My daughter is suffering from",
    "My child is suffering from",
    "I don't feel well, I have"
]

# Get some examples of users describing different number of symtoms 

for symptoms_count in number_of_symtoms:
    
    # make 100 example of each number of symtoms 
    for ex in range(1, 101):
        
        description_beginning = random.choice(start_of_description)
        
        # collect some random symtoms 
        symptom_1 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_2 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_3 = symptom_df['symptom'].sample(1).iloc[0].lower()
        symptom_4 = symptom_df['symptom'].sample(1).iloc[0].lower()
        
        symptoms = [symptom_1, symptom_2, symptom_3, symptom_4]
        symptom_entity = []
        
        # Remove paranthases from symptoms and add nessecary entity tags to symtoms 
        for symptom in symptoms:
            symptom = re.sub(r"\([^)]+\)", "", symptom).strip()
            symptom = f"[{symptom}](symptom)"
            symptom_entity.append(symptom)
            
        symptom_1 = symptom_entity[0]
        symptom_2 = symptom_entity[1]
        symptom_3 = symptom_entity[2]
        symptom_4 = symptom_entity[3]
        
        # Create the training sample strig 
        
        if symptoms_count == 1:
            
            symptom_string = f"- {description_beginning} {symptom_1}"
            
        if symptoms_count == 2:
            
            symptom_string = f"- {description_beginning} {symptom_1} and {symptom_2}"
            
        if symptoms_count == 3:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, and {symptom_3}"
            
        if symptoms_count == 4:
            
            symptom_string = f"- {description_beginning} {symptom_1}, {symptom_2}, {symptom_3}, {symptom_4}"
        
        print(symptom_string)
# Out:
# - I'm suffering from [flatulence](symptom)
# - My child is suffering from [darkening of the skin](symptom)
# - For the last few days I have had [scrotal pain](symptom)
# - My husband is suffering from [joint pain](symptom)
# - My symptoms are [agitated](symptom)
# - I have [liver failure](symptom)
# - My daughter is suffering from [heel pain](symptom)
# - I don't feel well, I have [alcohol abuse](symptom)
# - I have really bad [rash](symptom)
# - My son is suffering from [abscess](symptom)
# - My husband is suffering from [elbow swelling](symptom)
# - My wife is suffering from [tongue swelling](symptom)
# - I don't feel well, I have [diarrhea](symptom)
# - My wife is suffering from [ringing in ears](symptom)
# - My son is suffering from [shoulder ache or pain](symptom)
# - I'm suffering from [back ache or pain](symptom)
# - My husband is suffering from [skin pain](symptom)
# - I'm suffering from [painful urination](symptom)
# - My wife is suffering from [skin bumps](symptom)
# - My daughter is suffering from [bloody diarrhea](symptom)
# - I don't feel well, I have [arm swelling](symptom)
# - I have [scrotal pain](symptom)
# - My wife is suffering from [swelling](symptom)
# - I have [hurts to breathe](symptom)
# - I have [delusions or hallucinations](symptom)
# - My wife is suffering from [behavioral problem](symptom)
# - My wife is suffering from [night sweats](symptom)
# - My son is suffering from [hand cut](symptom)
# - My daughter is suffering from [lip swelling](symptom)
# - I'm suffering from [back ache or pain](symptom)
# - I have really bad [nasal bleeding](symptom)
# - My child is suffering from [anger](symptom)
# - I'm suffering from [heart pulsations and palpitations](symptom)
# - I have [headache](symptom)
# - I have really bad [hot skin](symptom)
# - My symptoms are [anger](symptom)
# - I'm suffering from [fever in the returning traveler](symptom)
# - My daughter is suffering from [foot redness](symptom)
# - I have really bad [blister](symptom)
# - My child is suffering from [drooping eyelid](symptom)
# - My husband is suffering from [maroon stools](symptom)
# - My husband is suffering from [spider bite](symptom)
# - My daughter is suffering from [scrotal swelling](symptom)
# - My husband is suffering from [eye swelling](symptom)
# - I have [snake bite](symptom)
# - I have really bad [increased facial hair](symptom)
# - I don't feel well, I have [loss of balance](symptom)
# - My daughter is suffering from [eye pain](symptom)
# - My symptoms are [pain or soreness of breast](symptom)
# - My husband is suffering from [vaginal bleeding](symptom)
# - My husband is suffering from [heat illness](symptom)
# - I have [snake bite](symptom)
# - My symptoms are [foot redness](symptom)
# - My child is suffering from [headache](symptom)
# - My daughter is suffering from [sore throat](symptom)
# - My husband is suffering from [leg cut](symptom)
# - My son is suffering from [diarrhea](symptom)
# - My wife is suffering from [incontinence](symptom)
# - My daughter is suffering from [ear pressure](symptom)
# - For the last few days I have had [pelvic pain](symptom)
# - My symptoms are [fever in the returning traveler](symptom)
# - My daughter is suffering from [difficulty breathing](symptom)
# - My daughter is suffering from [facial droop](symptom)
# - I don't feel well, I have [hip pain](symptom)
# - For the last few days I have had [memory loss](symptom)
# - My wife is suffering from [snoring](symptom)
# - For the last few days I have had [snake bite](symptom)
# - I don't feel well, I have [wrist swelling](symptom)
# - I'm suffering from [penis inflammation or swelling](symptom)
# - I don't feel well, I have [abscess](symptom)
# - My child is suffering from [shin pain](symptom)
# - My son is suffering from [nasal congestion](symptom)
# - For the last few days I have had [hair loss](symptom)
# - I'm suffering from [leg cut](symptom)
# - I don't feel well, I have [snake bite](symptom)
# - I have really bad [visual problems](symptom)
# - I'm suffering from [overdose](symptom)
# - My child is suffering from [unusual color or odor of urine](symptom)
# - I have really bad [shoulder ache or pain](symptom)
# - I'm suffering from [nasal bleeding](symptom)
# - I have [insomnia](symptom)
# - I have really bad [visual problems](symptom)
# - My wife is suffering from [vertigo](symptom)
# - My symptoms are [mouth ulcers](symptom)
# - My husband is suffering from [scrotal swelling](symptom)
# - I don't feel well, I have [scrotal pain](symptom)
# - My son is suffering from [pregnancy problem](symptom)
# - I'm suffering from [learning difficulties](symptom)
# - My son is suffering from [darkening of the skin](symptom)
# - My child is suffering from [insomnia](symptom)
# - My son is suffering from [penis inflammation or swelling](symptom)
# - I have [visual flashing lights](symptom)
# - My symptoms are [face numbness](symptom)
# - I don't feel well, I have [dark stools](symptom)
# - My wife is suffering from [excessive appetite](symptom)
# - I have really bad [vaginal discharge](symptom)
# - I'm suffering from [lump or mass of breast](symptom)
# - For the last few days I have had [mouth pain](symptom)
# - For the last few days I have had [hair loss](symptom)
# - I'm suffering from [heel pain](symptom)
# - I have really bad [low heart rate](symptom) and [swallowing problem](symptom)
# - For the last few days I have had [arm swelling](symptom) and [high blood pressure](symptom)
# - My daughter is suffering from [sleep disorders](symptom) and [eye redness](symptom)
# - My wife is suffering from [facial droop](symptom) and [shin pain](symptom)
# - My wife is suffering from [throat pain](symptom) and [hand itching](symptom)
# - My wife is suffering from [swallowing problem](symptom) and [speech problem](symptom)
# - My daughter is suffering from [amenorrhea](symptom) and [headache after trauma](symptom)
# - I'm suffering from [night sweats](symptom) and [vaginal bleeding after menopause](symptom)
# - I have really bad [tooth pain](symptom) and [arm itching](symptom)
# - I don't feel well, I have [elbow ache or pain](symptom) and [muscle pain](symptom)
# - I have really bad [anxiety](symptom) and [neck swelling](symptom)
# - My husband is suffering from [foot redness](symptom) and [hoarse voice](symptom)
# - My symptoms are [skin pain](symptom) and [painful rash](symptom)
# - My symptoms are [painful urination](symptom) and [throat pain](symptom)
# - I'm suffering from [shoulder stiffness or tightness](symptom) and [tongue swelling](symptom)
# - I'm suffering from [hot flashes](symptom) and [snoring](symptom)
# - My husband is suffering from [sweating](symptom) and [foot cut](symptom)
# - My symptoms are [skin pain](symptom) and [ear swelling](symptom)
# - I have [lump or mass of breast](symptom) and [hurts to breathe](symptom)
# - My wife is suffering from [eye floaters](symptom) and [upper abdominal pain](symptom)
# - My child is suffering from [hand itching](symptom) and [flank pain](symptom)
# - My son is suffering from [high blood pressure](symptom) and [drooping eyelid](symptom)
# - My wife is suffering from [vaginal pain](symptom) and [chest pain](symptom)
# - I don't feel well, I have [penile discharge](symptom) and [ankle pain](symptom)
# - I'm suffering from [swollen lymph nodes](symptom) and [hand numbness](symptom)
# - I'm suffering from [darkening of the skin](symptom) and [headache after trauma](symptom)
# - I have [dementia](symptom) and [muscle spasm](symptom)
# - My child is suffering from [insomnia](symptom) and [skin infection](symptom)
# - I don't feel well, I have [constipation](symptom) and [darkening of the skin](symptom)
# - For the last few days I have had [night sweats](symptom) and [hand cut](symptom)
# - I have really bad [swelling of both legs](symptom) and [urinary retention](symptom)
# - My wife is suffering from [fever of unknown origin](symptom) and [leg itching](symptom)
# - My husband is suffering from [facial pain](symptom) and [low back ache or pain](symptom)
# - My symptoms are [penile discharge](symptom) and [lethargy](symptom)
# - My symptoms are [incontinence](symptom) and [alcohol abuse](symptom)
# - I have really bad [urinary retention](symptom) and [arm swelling](symptom)
# - My symptoms are [wrist pain](symptom) and [flank pain](symptom)
# - My son is suffering from [painful rash](symptom) and [skin bumps](symptom)
# - I don't feel well, I have [agitated](symptom) and [tooth pain](symptom)
# - For the last few days I have had [nail injury](symptom) and [dry skin](symptom)
# - My son is suffering from [pulling at ears](symptom) and [lethargy](symptom)
# - My wife is suffering from [confusion and headache](symptom) and [hand, finger ache or pain](symptom)
# - My child is suffering from [blister](symptom) and [foot cut](symptom)
# - I have [swallowing problem](symptom) and [difficulty breathing](symptom)
# - I don't feel well, I have [unusual color or odor of urine](symptom) and [shin pain](symptom)
# - My wife is suffering from [muscle spasm](symptom) and [painful urination](symptom)
# - I have really bad [liver failure](symptom) and [heat illness](symptom)
# - My daughter is suffering from [chest pain](symptom) and [nipple discharge](symptom)
# - My symptoms are [retaining fluid](symptom) and [dementia](symptom)
# - I don't feel well, I have [agitated](symptom) and [vaginal discharge](symptom)
# - I don't feel well, I have [eye swelling](symptom) and [pregnancy problem](symptom)
# - My son is suffering from [foot pain](symptom) and [memory loss](symptom)
# - My daughter is suffering from [abscess](symptom) and [sneezing](symptom)
# - My son is suffering from [drooling](symptom) and [maroon stools](symptom)
# - My symptoms are [agitated](symptom) and [vaginal discharge](symptom)
# - I don't feel well, I have [toe pain](symptom) and [nipple discharge](symptom)
# - My son is suffering from [lethargy](symptom) and [difficulty breathing](symptom)
# - I have [trauma](symptom) and [cranky, crying, fussy, irritable child](symptom)
# - My daughter is suffering from [calf swelling](symptom) and [weight loss, unexplained](symptom)
# - My child is suffering from [eye floaters](symptom) and [eye floaters](symptom)
# - My husband is suffering from [heat illness](symptom) and [overdose](symptom)
# - I'm suffering from [vaginal bleeding after menopause](symptom) and [ear swelling](symptom)
# - My husband is suffering from [jaw pain](symptom) and [eye swelling](symptom)
# - I have [chest pressure](symptom) and [anxiety](symptom)
# - My son is suffering from [spider bite](symptom) and [skin bumps](symptom)
# - I don't feel well, I have [pregnancy problem](symptom) and [mouth swelling](symptom)
# - I have really bad [alcohol abuse](symptom) and [speech problem](symptom)
# - I don't feel well, I have [leg ache or pain](symptom) and [abdominal swelling](symptom)
# - My child is suffering from [cough](symptom) and [lethargy](symptom)
# - My husband is suffering from [heat illness](symptom) and [low back ache or pain](symptom)
# - My symptoms are [vaginal bleeding after menopause](symptom) and [congestion in chest or lungs](symptom)
# - I have really bad [skin swelling](symptom) and [drooling](symptom)
# - My daughter is suffering from [hand cut](symptom) and [leg ache or pain](symptom)
# - My child is suffering from [vomiting](symptom) and [ingestion](symptom)
# - My wife is suffering from [rectal pain](symptom) and [high blood pressure](symptom)
# - I have really bad [numbness](symptom) and [low back ache or pain](symptom)
# - I have really bad [change in behavior](symptom) and [scrotal swelling](symptom)
# - My son is suffering from [frequent urination](symptom) and [arm cut](symptom)
# - I have [joint stiffness](symptom) and [vaginal pain](symptom)
# - I have [hypothermia](symptom) and [vaginal bleeding](symptom)
# - My symptoms are [depressed](symptom) and [mouth ulcers](symptom)
# - My daughter is suffering from [anger](symptom) and [hurts to breathe](symptom)
# - My husband is suffering from [mouth swelling](symptom) and [arm stiffness or tightness](symptom)
# - I'm suffering from [throat pain](symptom) and [weight loss, unexplained](symptom)
# - I have [visual problems](symptom) and [tooth pain](symptom)
# - I'm suffering from [bleeding gums](symptom) and [urinary retention](symptom)
# - I'm suffering from [congestion in chest or lungs](symptom) and [ringing in ears](symptom)
# - My daughter is suffering from [bleeding tendency](symptom) and [seizure](symptom)
# - My symptoms are [fever](symptom) and [leg itching](symptom)
# - My husband is suffering from [facial pain](symptom) and [liver failure](symptom)
# - My husband is suffering from [ear swelling](symptom) and [ear pressure](symptom)
# - I have [stomach and abdominal pain](symptom) and [fainting](symptom)
# - My husband is suffering from [suicidal tendencies](symptom) and [ear pressure](symptom)
# - My symptoms are [loss of balance](symptom) and [impotence](symptom)
# - My son is suffering from [snoring](symptom) and [foot cut](symptom)
# - I have really bad [facial pain](symptom) and [painful urination](symptom)
# - My wife is suffering from [unsteady gait](symptom) and [ankle pain](symptom)
# - For the last few days I have had [hot flashes](symptom) and [hair loss](symptom)
# - My husband is suffering from [shoulder stiffness or tightness](symptom) and [double vision](symptom)
# - For the last few days I have had [limping in a child](symptom) and [heel pain](symptom)
# - My daughter is suffering from [wrist pain](symptom), [skin growths](symptom), and [bleeding gums](symptom)
# - My husband is suffering from [tired](symptom), [throat pain](symptom), and [obesity](symptom)
# - I have [head injury](symptom), [snake bite](symptom), and [speech problem](symptom)
# - My wife is suffering from [neck stiffness or tightness](symptom), [vaginal discharge](symptom), and [limping in a child](symptom)
# - My daughter is suffering from [upper abdominal pain](symptom), [general weakness](symptom), and [foot pain](symptom)
# - I have really bad [chest burning](symptom), [flatulence](symptom), and [armpit pain](symptom)
# - My daughter is suffering from [melena](symptom), [headache](symptom), and [cranky, crying, fussy, irritable child](symptom)
# - My child is suffering from [night sweats](symptom), [fever](symptom), and [itchy eyes](symptom)
# - I have really bad [sore throat](symptom), [double vision](symptom), and [calf swelling](symptom)
# - I don't feel well, I have [alcohol abuse](symptom), [visual flashing lights](symptom), and [vaginal bleeding after menopause](symptom)
# - My wife is suffering from [bleeding in brain](symptom), [delusions or hallucinations](symptom), and [hot flashes](symptom)
# - I don't feel well, I have [increased thirst](symptom), [nasal bleeding](symptom), and [fever in the returning traveler](symptom)
# - My daughter is suffering from [bloody diarrhea](symptom), [penis inflammation or swelling](symptom), and [learning difficulties](symptom)
# - For the last few days I have had [skin sores](symptom), [dark stools](symptom), and [stings](symptom)
# - My husband is suffering from [night sweats](symptom), [difficulty breathing](symptom), and [hand redness](symptom)
# - My child is suffering from [foot pain](symptom), [steatorrhea](symptom), and [liver failure](symptom)
# - My symptoms are [foot itching](symptom), [vaginal bleeding](symptom), and [heel pain](symptom)
# - I have really bad [loss of balance](symptom), [hand redness](symptom), and [vaginal bleeding during pregnancy](symptom)
# - For the last few days I have had [low heart rate](symptom), [neck stiffness or tightness](symptom), and [face numbness](symptom)
# - My husband is suffering from [skin trauma](symptom), [chest burning](symptom), and [insect sting](symptom)
# - I'm suffering from [penile discharge](symptom), [throat pain](symptom), and [loss of balance](symptom)
# - I'm suffering from [arm cut](symptom), [hand, finger ache or pain](symptom), and [wrist pain](symptom)
# - My symptoms are [fever](symptom), [weight loss, unexplained](symptom), and [ear swelling](symptom)
# - I'm suffering from [hoarse voice](symptom), [throat pain](symptom), and [low blood pressure](symptom)
# - My husband is suffering from [impotence](symptom), [ankle pain](symptom), and [retaining fluid](symptom)
# - For the last few days I have had [visual problems](symptom), [retaining fluid](symptom), and [loss of balance](symptom)
# - I don't feel well, I have [chest burning](symptom), [flank pain](symptom), and [overdose](symptom)
# - I have really bad [hand numbness](symptom), [swollen gums](symptom), and [facial pain](symptom)
# - My symptoms are [nipple discharge](symptom), [skin swelling](symptom), and [hypothermia](symptom)
# - My symptoms are [learning difficulties](symptom), [dizziness](symptom), and [fever of unknown origin](symptom)
# - I have really bad [lethargy](symptom), [swallowing problem](symptom), and [throat pain](symptom)
# - I have really bad [hand numbness](symptom), [face numbness](symptom), and [nasal bleeding](symptom)
# - My wife is suffering from [inconsolable baby](symptom), [arm ache or pain](symptom), and [wrist swelling](symptom)
# - My husband is suffering from [seizure](symptom), [headache after trauma](symptom), and [poisoning](symptom)
# - For the last few days I have had [vaginal itching](symptom), [steatorrhea](symptom), and [overdose](symptom)
# - I have really bad [joint stiffness](symptom), [bleeding gums](symptom), and [swollen lymph nodes](symptom)
# - My symptoms are [ingestion](symptom), [rash](symptom), and [headache after trauma](symptom)
# - My wife is suffering from [arm numbness](symptom), [upper abdominal pain](symptom), and [mouth swelling](symptom)
# - My wife is suffering from [vertigo](symptom), [stings](symptom), and [obesity](symptom)
# - My symptoms are [liver failure](symptom), [shortness of breath](symptom), and [failure to thrive](symptom)
# - I'm suffering from [seizure](symptom), [diarrhea](symptom), and [painful rash](symptom)
# - My daughter is suffering from [puncture wound](symptom), [flank pain](symptom), and [traveler's diarrhea](symptom)
# - I don't feel well, I have [trauma](symptom), [tremors](symptom), and [hand numbness](symptom)
# - My daughter is suffering from [swollen lymph nodes](symptom), [retaining fluid](symptom), and [trauma](symptom)
# - My wife is suffering from [itchy eyes](symptom), [fever in the returning traveler](symptom), and [facial droop](symptom)
# - My child is suffering from [eye redness](symptom), [rectal pain](symptom), and [blurry vision](symptom)
# - I have [pregnancy problem](symptom), [abscess](symptom), and [arm cut](symptom)
# - I have really bad [pregnancy problem](symptom), [dementia](symptom), and [learning difficulties](symptom)
# - My symptoms are [upper leg pain](symptom), [dementia](symptom), and [shoulder stiffness or tightness](symptom)
# - I don't feel well, I have [facial pain](symptom), [laceration](symptom), and [leg redness](symptom)
# - My husband is suffering from [liver failure](symptom), [shoulder stiffness or tightness](symptom), and [rash](symptom)
# - My symptoms are [alcohol abuse](symptom), [trauma](symptom), and [calf pain](symptom)
# - For the last few days I have had [sinus pain and pressure](symptom), [sweating](symptom), and [traveler's diarrhea](symptom)
# - I don't feel well, I have [weight loss, unexplained](symptom), [vaginal discharge](symptom), and [high blood pressure](symptom)
# - My wife is suffering from [tired](symptom), [vaginal bleeding after menopause](symptom), and [infertility](symptom)
# - I don't feel well, I have [anxiety](symptom), [flank pain](symptom), and [scrotal pain](symptom)
# - My son is suffering from [substance abuse](symptom), [choking](symptom), and [bleeding gums](symptom)
# - My child is suffering from [face numbness](symptom), [sweating](symptom), and [vaginal pain](symptom)
# - My son is suffering from [retaining fluid](symptom), [stings](symptom), and [bloody diarrhea](symptom)
# - I have [knee pain](symptom), [calf swelling](symptom), and [wheezing](symptom)
# - I have [liver failure](symptom), [swelling](symptom), and [fainting](symptom)
# - My symptoms are [urinary retention](symptom), [learning difficulties](symptom), and [muscle spasm](symptom)
# - I don't feel well, I have [hemoptysis](symptom), [ear swelling](symptom), and [leg numbness](symptom)
# - My son is suffering from [penis pain](symptom), [increased facial hair](symptom), and [maroon stools](symptom)
# - My child is suffering from [anger](symptom), [swallowing problem](symptom), and [wrist swelling](symptom)
# - My daughter is suffering from [high blood sugar](symptom), [back ache or pain](symptom), and [painful urination](symptom)
# - For the last few days I have had [pustule](symptom), [loss of balance](symptom), and [wrist swelling](symptom)
# - My son is suffering from [discharge from ear](symptom), [vaginal discharge](symptom), and [muscle pain](symptom)
# - My son is suffering from [numbness](symptom), [drooping eyelid](symptom), and [nasal bleeding](symptom)
# - I'm suffering from [infertility](symptom), [neck swelling](symptom), and [headache after trauma](symptom)
# - My husband is suffering from [diarrhea](symptom), [fever in the returning traveler](symptom), and [joint stiffness](symptom)
# - I have really bad [ear pressure](symptom), [scrotal swelling](symptom), and [speech problem](symptom)
# - My daughter is suffering from [hemoptysis](symptom), [hand, finger ache or pain](symptom), and [toe pain](symptom)
# - For the last few days I have had [ankle pain](symptom), [hair loss](symptom), and [laceration](symptom)
# - For the last few days I have had [tongue swelling](symptom), [flatulence](symptom), and [eye floaters](symptom)
# - I have really bad [liver failure](symptom), [fever of unknown origin](symptom), and [nail injury](symptom)
# - I have [throat pain](symptom), [stomach and abdominal pain](symptom), and [agitated](symptom)
# - I have [vaginal bleeding](symptom), [skin infection](symptom), and [weight loss, unexplained](symptom)
# - My child is suffering from [painful gums](symptom), [bloody diarrhea](symptom), and [joint stiffness](symptom)
# - I have [blood in urine](symptom), [foot itching](symptom), and [hypothermia](symptom)
# - My daughter is suffering from [delusions or hallucinations](symptom), [infertility](symptom), and [vaginal bleeding](symptom)
# - I have really bad [flank pain](symptom), [vaginal discharge](symptom), and [foot swelling](symptom)
# - I don't feel well, I have [blurry vision](symptom), [drooping eyelid](symptom), and [ringing in ears](symptom)
# - For the last few days I have had [abscess](symptom), [lip swelling](symptom), and [excessive appetite](symptom)
# - My wife is suffering from [laceration](symptom), [snoring](symptom), and [calf swelling](symptom)
# - For the last few days I have had [calf pain](symptom), [vomiting coffee ground material](symptom), and [snoring](symptom)
# - My child is suffering from [sweating](symptom), [dark stools](symptom), and [liver failure](symptom)
# - My symptoms are [vaginal bleeding during pregnancy](symptom), [abscess](symptom), and [shoulder ache or pain](symptom)
# - I have really bad [tongue swelling](symptom), [headache and weakness](symptom), and [double vision](symptom)
# - I'm suffering from [impotence](symptom), [wheezing](symptom), and [neck stiffness or tightness](symptom)
# - My child is suffering from [fever in the returning traveler](symptom), [seizure](symptom), and [lump or mass of breast](symptom)
# - I don't feel well, I have [headache after trauma](symptom), [vaginal bleeding during pregnancy](symptom), and [pelvic pain](symptom)
# - My son is suffering from [scrotal pain](symptom), [muscle spasm](symptom), and [calf pain](symptom)
# - I have [shoulder ache or pain](symptom), [vaginal bleeding during pregnancy](symptom), and [suicidal tendencies](symptom)
# - I have really bad [nasal injury](symptom), [toe pain](symptom), and [rectal pain](symptom)
# - My son is suffering from [drooping eyelid](symptom), [foot cut](symptom), and [overdose](symptom)
# - I'm suffering from [urinary retention](symptom), [drooling](symptom), and [hand numbness](symptom)
# - I have [foot redness](symptom), [constipation](symptom), and [skin swelling](symptom)
# - My symptoms are [head injury](symptom), [skin trauma](symptom), and [headache after trauma](symptom)
# - My husband is suffering from [painful gums](symptom), [loss of balance](symptom), and [leg redness](symptom)
# - I have really bad [low blood pressure](symptom), [congestion in chest or lungs](symptom), [chills](symptom), [skin sores](symptom)
# - For the last few days I have had [rectal pain](symptom), [seizure](symptom), [low blood sugar](symptom), [cranky, crying, fussy, irritable child](symptom)
# - I don't feel well, I have [high blood sugar](symptom), [joint pain](symptom), [pregnancy problem](symptom), [fever of unknown origin](symptom)
# - My husband is suffering from [throat pain](symptom), [skin pain](symptom), [hair loss](symptom), [leg redness](symptom)
# - My wife is suffering from [hand numbness](symptom), [pain in the ear](symptom), [lethargy](symptom), [hemoptysis](symptom)
# - I have [hair loss](symptom), [head injury](symptom), [elbow swelling](symptom), [increased thirst](symptom)
# - My husband is suffering from [inconsolable baby](symptom), [tired](symptom), [rectal swelling](symptom), [infertility](symptom)
# - My symptoms are [steatorrhea](symptom), [upper abdominal pain](symptom), [hand cut](symptom), [loss of balance](symptom)
# - I have [hot skin](symptom), [tremors](symptom), [numbness](symptom), [hip pain](symptom)
# - I have really bad [nasal congestion](symptom), [painful gums](symptom), [shoulder stiffness or tightness](symptom), [mouth ulcers](symptom)
# - I have really bad [choking](symptom), [high blood sugar](symptom), [infertility](symptom), [vaginal bleeding during pregnancy](symptom)
# - I'm suffering from [general weakness](symptom), [knee pain](symptom), [urinary retention](symptom), [nail injury](symptom)
# - For the last few days I have had [skin bumps](symptom), [lower abdominal pain](symptom), [psychiatric problem](symptom), [laceration](symptom)
# - My daughter is suffering from [diarrhea](symptom), [foot redness](symptom), [swollen gums](symptom), [vaginal bleeding after menopause](symptom)
# - My child is suffering from [swallowing problem](symptom), [hot flashes](symptom), [sneezing](symptom), [tooth pain](symptom)
# - I don't feel well, I have [jaw pain](symptom), [dizziness](symptom), [fever of unknown origin](symptom), [hand cut](symptom)
# - My husband is suffering from [obesity](symptom), [mouth pain](symptom), [ankle pain](symptom), [skin sores](symptom)
# - My wife is suffering from [vaginal pain](symptom), [maroon stools](symptom), [jaw pain](symptom), [upper abdominal pain](symptom)
# - My daughter is suffering from [mouth pain](symptom), [foot redness](symptom), [agitated](symptom), [melena](symptom)
# - My daughter is suffering from [lip swelling](symptom), [foot pain](symptom), [knee pain](symptom), [tooth pain](symptom)
# - My husband is suffering from [hand redness](symptom), [neck ache or pain](symptom), [hand redness](symptom), [shin pain](symptom)
# - My child is suffering from [lethargy](symptom), [maroon stools](symptom), [face numbness](symptom), [head injury](symptom)
# - My daughter is suffering from [hand itching](symptom), [foot numbness](symptom), [trauma](symptom), [inconsolable baby](symptom)
# - My husband is suffering from [skin itching](symptom), [memory loss](symptom), [agitated](symptom), [confusion and headache](symptom)
# - For the last few days I have had [pregnancy problem](symptom), [vaginal pain](symptom), [arm redness](symptom), [skin itching](symptom)
# - My daughter is suffering from [facial droop](symptom), [drooling](symptom), [snake bite](symptom), [arm stiffness or tightness](symptom)
# - I have [leg redness](symptom), [swollen lymph nodes](symptom), [low blood pressure](symptom), [leg ache or pain](symptom)
# - I have really bad [arm numbness](symptom), [spider bite](symptom), [painful rash](symptom), [change in behavior](symptom)
# - For the last few days I have had [low blood sugar](symptom), [hypothermia](symptom), [psychiatric problem](symptom), [mouth pain](symptom)
# - I'm suffering from [insomnia](symptom), [abdominal swelling](symptom), [suicidal tendencies](symptom), [blurry vision](symptom)
# - I'm suffering from [limping in a child](symptom), [head injury](symptom), [nipple discharge](symptom), [visual problems](symptom)
# - My child is suffering from [dizziness](symptom), [chest burning](symptom), [memory loss](symptom), [hair loss](symptom)
# - My daughter is suffering from [unusual color or odor of urine](symptom), [confusion](symptom), [mouth pain](symptom), [flank pain](symptom)
# - My husband is suffering from [visual flashing lights](symptom), [suicidal tendencies](symptom), [insect sting](symptom), [heat illness](symptom)
# - My daughter is suffering from [neck swelling](symptom), [vomiting](symptom), [vaginal bleeding after menopause](symptom), [hand itching](symptom)
# - I have really bad [sneezing](symptom), [high blood pressure](symptom), [pregnancy problem](symptom), [failure to thrive](symptom)
# - My wife is suffering from [vaginal itching](symptom), [tooth pain](symptom), [shin pain](symptom), [liver failure](symptom)
# - My child is suffering from [fainting](symptom), [chest pressure](symptom), [seizure](symptom), [skin trauma](symptom)
# - My wife is suffering from [tremors](symptom), [high blood pressure](symptom), [dementia](symptom), [elbow swelling](symptom)
# - For the last few days I have had [leg itching](symptom), [hot flashes](symptom), [blood in vomit](symptom), [penile discharge](symptom)
# - I have [congestion in chest or lungs](symptom), [ankle pain](symptom), [infertility](symptom), [fever in the returning traveler](symptom)
# - I don't feel well, I have [sneezing](symptom), [stomach and abdominal pain](symptom), [low blood sugar](symptom), [pelvic pain](symptom)
# - I have [abdominal swelling](symptom), [congestion in chest or lungs](symptom), [low heart rate](symptom), [joint stiffness](symptom)
# - My husband is suffering from [low heart rate](symptom), [joint pain](symptom), [neck ache or pain](symptom), [blood in vomit](symptom)
# - My daughter is suffering from [scrotal pain](symptom), [mouth ulcers](symptom), [dementia](symptom), [increased urination](symptom)
# - I'm suffering from [headache and weakness](symptom), [skin itching](symptom), [pain in the ear](symptom), [cough](symptom)
# - My wife is suffering from [arm itching](symptom), [vertigo](symptom), [arm cut](symptom), [penis inflammation or swelling](symptom)
# - I'm suffering from [laceration](symptom), [spider bite](symptom), [leg ache or pain](symptom), [pelvic pain](symptom)
# - I have [stings](symptom), [constipation](symptom), [heel pain](symptom), [snake bite](symptom)
# - For the last few days I have had [diarrhea](symptom), [agitated](symptom), [upper abdominal pain](symptom), [ingestion](symptom)
# - My son is suffering from [flank pain](symptom), [hives](symptom), [foot swelling](symptom), [delusions or hallucinations](symptom)
# - My wife is suffering from [substance abuse](symptom), [pulling at ears](symptom), [snake bite](symptom), [choking](symptom)
# - My husband is suffering from [back ache or pain](symptom), [poisoning](symptom), [shortness of breath](symptom), [unsteady gait](symptom)
# - I don't feel well, I have [dry skin](symptom), [skin infection](symptom), [excessive appetite](symptom), [skin infection](symptom)
# - I'm suffering from [pulling at ears](symptom), [vaginal pain](symptom), [tired](symptom), [lethargy](symptom)
# - For the last few days I have had [hand, finger ache or pain](symptom), [skin swelling](symptom), [neck ache or pain](symptom), [skin pain](symptom)
# - My child is suffering from [skin pain](symptom), [upper leg pain](symptom), [skin itching](symptom), [joint stiffness](symptom)
# - My child is suffering from [alcohol abuse](symptom), [shortness of breath](symptom), [lower abdominal pain](symptom), [abscess](symptom)
# - My husband is suffering from [jaundice](symptom), [nasal bleeding](symptom), [pulling at ears](symptom), [back ache or pain](symptom)
# - I have [swelling](symptom), [limping in a child](symptom), [dry skin](symptom), [unusual color or odor of urine](symptom)
# - My son is suffering from [ringing in ears](symptom), [insomnia](symptom), [fever in the returning traveler](symptom), [painful rash](symptom)
# - My son is suffering from [rectal pain](symptom), [rectal swelling](symptom), [confusion and headache](symptom), [spider bite](symptom)
# - I'm suffering from [knee pain](symptom), [spider bite](symptom), [skin itching](symptom), [ankle pain](symptom)
# - I have really bad [abdominal swelling](symptom), [vaginal bleeding after menopause](symptom), [skin swelling](symptom), [blister](symptom)
# - My son is suffering from [shoulder ache or pain](symptom), [difficulty breathing](symptom), [high blood sugar](symptom), [sinus pain and pressure](symptom)
# - My symptoms are [hip pain](symptom), [jaundice](symptom), [nipple discharge](symptom), [poisoning](symptom)
# - I have really bad [painful gums](symptom), [overdose](symptom), [kidney pain](symptom), [blood in urine](symptom)
# - For the last few days I have had [wrist pain](symptom), [facial pain](symptom), [poisoning](symptom), [foot redness](symptom)
# - For the last few days I have had [cyanosis](symptom), [nipple discharge](symptom), [abscess](symptom), [inconsolable baby](symptom)
# - For the last few days I have had [kidney pain](symptom), [hemoptysis](symptom), [hand redness](symptom), [kidney pain](symptom)
# - I have [hip pain](symptom), [shortness of breath](symptom), [painful gums](symptom), [rectal swelling](symptom)
# - My wife is suffering from [hoarse voice](symptom), [rash](symptom), [wrist swelling](symptom), [excessive appetite](symptom)
# - My wife is suffering from [failure to thrive](symptom), [dizziness](symptom), [abdominal swelling](symptom), [agitated](symptom)
# - I don't feel well, I have [lip swelling](symptom), [vaginal itching](symptom), [foot itching](symptom), [general weakness](symptom)
# - I have [blood in vomit](symptom), [pulling at ears](symptom), [incontinence](symptom), [inconsolable baby](symptom)
# - My daughter is suffering from [arm swelling](symptom), [face numbness](symptom), [mouth swelling](symptom), [pulling at ears](symptom)
# - My wife is suffering from [trauma](symptom), [knee pain](symptom), [loss of balance](symptom), [trauma](symptom)
# - My symptoms are [puncture wound](symptom), [pain or soreness of breast](symptom), [hives](symptom), [frequent urination](symptom)
# - My husband is suffering from [cranky, crying, fussy, irritable child](symptom), [headache after trauma](symptom), [chest pressure](symptom), [seizure](symptom)
# - I have really bad [confusion](symptom), [chest burning](symptom), [laceration](symptom), [wrist swelling](symptom)
# - For the last few days I have had [pelvic pain](symptom), [penile discharge](symptom), [arm ache or pain](symptom), [sore throat](symptom)
# - My symptoms are [jaundice](symptom), [back ache or pain](symptom), [lump or mass of breast](symptom), [armpit pain](symptom)
# - My husband is suffering from [blood in urine](symptom), [armpit pain](symptom), [rash](symptom), [throat pain](symptom)
# - My symptoms are [nasal bleeding](symptom), [muscle spasm](symptom), [snake bite](symptom), [heat illness](symptom)
# - My symptoms are [confusion and headache](symptom), [increased thirst](symptom), [vomiting coffee ground material](symptom), [pelvic pain](symptom)
# - For the last few days I have had [stomach and abdominal pain](symptom), [toe pain](symptom), [skin pain](symptom), [urinary retention](symptom)
# - I have [loss of balance](symptom), [skin swelling](symptom), [bloody diarrhea](symptom), [fever in the returning traveler](symptom)
# - My wife is suffering from [night sweats](symptom), [heat illness](symptom), [leg numbness](symptom), [joint stiffness](symptom)
# - I don't feel well, I have [flatulence](symptom), [insomnia](symptom), [choking](symptom), [vaginal bleeding during pregnancy](symptom)
# - My son is suffering from [fever](symptom), [nausea](symptom), [urinary retention](symptom), [elbow ache or pain](symptom)
# - My symptoms are [tooth pain](symptom), [unusual color or odor of urine](symptom), [amenorrhea](symptom), [darkening of the skin](symptom)
# - I have really bad [blood in urine](symptom), [urinary retention](symptom), [itchy rash](symptom), [weight loss, unexplained](symptom)
# - I'm suffering from [shoulder ache or pain](symptom), [vaginal bleeding after menopause](symptom), [heat illness](symptom), [skin infection](symptom)
# - I have really bad [puncture wound](symptom), [arm stiffness or tightness](symptom), [tremors](symptom), [arm stiffness or tightness](symptom)
# - My wife is suffering from [drooling](symptom), [obesity](symptom), [heart pulsations and palpitations](symptom), [difficulty breathing](symptom)
# - My child is suffering from [stings](symptom), [fever of unknown origin](symptom), [retaining fluid](symptom), [puncture wound](symptom)
# - My child is suffering from [impotence](symptom), [penis pain](symptom), [fainting](symptom), [anger](symptom)
# - My son is suffering from [swollen lymph nodes](symptom), [penis pain](symptom), [facial droop](symptom), [hand, finger ache or pain](symptom)
# - I don't feel well, I have [arm stiffness or tightness](symptom), [hand itching](symptom), [tired](symptom), [eye redness](symptom)
# - I have [wrist pain](symptom), [chills](symptom), [neck stiffness or tightness](symptom), [hand itching](symptom)

# %%
source_data.to_pickle('input_data/diagnosis_data.pkl')

# %%
print(source_data.columns)
# Out:
# Index(['illness_id', 'symptom_id', 'illness', 'symptom'], dtype='object')
